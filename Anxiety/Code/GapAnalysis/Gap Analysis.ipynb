# %%
import pandas as pd

# %%
df=pd.read_csv("df3.csv")
df.head()
# Out:
#    Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,  \
# 0  Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 1  Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 2  Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 3  Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 4  Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
#
#    0.09999999999999998  Academic  2012  Topic9.0  treatment,  Reddit  2012.1  \
# 0                  0.1  Academic  2012  Topic9.0  treatment,  Reddit    2012
# 1                  0.1  Academic  2012  Topic9.0  treatment,  Reddit    2012
# 2                  0.1  Academic  2012  Topic9.0  treatment,  Reddit    2012
# 3                  0.1  Academic  2012  Topic9.0  treatment,  Reddit    2012
# 4                  0.1  Academic  2012  Topic9.0  treatment,  Reddit    2012
#
#    Topic2.0     ...       0  Academic_2012_Topic9.0_treatment,.1  57  9.0  \
# ...
