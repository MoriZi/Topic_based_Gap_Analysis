# %%
import pandas as pd

# %% [markdown]
# ### Academic 2012 vs Reddit 2012-2015

# %%
df=pd.read_csv("results_ga12.csv")
df=df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#                             source1_label                  source2_label  \
# 0       Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 1       Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 2       Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 3       Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 4       Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 5       Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 6       Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 7       Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 8       Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 9       Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 10      Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# 11      Academic_2012_Topic9.0_treatment,  Reddit_2012_Topic2.0_anxiety,
# ...

# %%
df.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    561281
# 0.09999999999999998     32767
# softcosine                  1
# dtype: int64

# %%
df2=pd.read_csv("res_ga13.csv")
df2=df2.loc[:, ~df2.columns.str.contains('^Unnamed')]
df2
# Out:
#                            source1_label                   source2_label  \
# 0       Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 1       Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 2       Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 3       Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 4       Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 5       Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 6       Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 7       Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 8       Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 9       Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 10      Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# 11      Academic_2012_Topic2.0_disorder,  Reddit_2013_Topic15.0_anxiety,
# ...

# %%
df2.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    494089
# 0.13710145950317382        20
# 0.2                     46782
# 0.09999999999999998     32767
# softcosine                  1
# dtype: int64

# %%
df3=pd.read_csv("res_ga14.csv")
df3=df3.loc[:, ~df3.columns.str.contains('^Unnamed')]
df3
# Out:
#                             source1_label               source2_label  \
# 0       Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 1       Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 2       Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 3       Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 4       Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 5       Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 6       Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 7       Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 8       Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 9       Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 10      Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# 11      Academic_2012_Topic6.0_treatment,  Reddit_2014_Topic7.0_feel,
# ...

# %%
df3.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    592503
# 0.2                      8786
# 0.09999999999999998     32767
# softcosine                  1
# dtype: int64

# %%
df4=pd.read_csv("res_ga15.csv")
df4=df4.loc[:, ~df4.columns.str.contains('^Unnamed')]
df4
# Out:
#                          source1_label                 source2_label  \
# 0        Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 1        Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 2        Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 3        Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 4        Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 5        Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 6        Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 7        Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 8        Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 9        Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 10       Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 11       Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# 12       Academic_2012_Topic16.0_self,     Reddit_2015_Topic52.0_be,
# ...

# %%
df4.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    618437
# 0.09999999999999998     32767
# softcosine                  1
# dtype: int64

# %% [markdown]
# ### Academic 2013- Reddit 2012-2015

# %%
df5=pd.read_csv("resj13_ga12.csv")
df5=df5.loc[:, ~df5.columns.str.contains('^Unnamed')]
df5
# Out:
#                            source1_label                  source2_label  \
# 0          Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 1          Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 2          Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 3          Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 4          Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 5          Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 6          Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 7          Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 8          Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 9          Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 10         Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# 11         Academic_2013_Topic1.0_scale,  Reddit_2012_Topic2.0_anxiety,
# ...

# %%
df5.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1276313
# 0.09999999999999998      32767
# softcosine                   1
# dtype: int64

# %%
df6=pd.read_csv("resj13_ga13.csv")
df6=df6.loc[:, ~df6.columns.str.contains('^Unnamed')]
df6
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (2,4,8,11,13,14,15,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                               source1_label                   source2_label  \
# 0             Academic_2013_Topic1.0_scale,  Reddit_2013_Topic15.0_anxiety,
# 1             Academic_2013_Topic1.0_scale,  Reddit_2013_Topic15.0_anxiety,
# 2             Academic_2013_Topic1.0_scale,  Reddit_2013_Topic15.0_anxiety,
# 3             Academic_2013_Topic1.0_scale,  Reddit_2013_Topic15.0_anxiety,
# 4             Academic_2013_Topic1.0_scale,  Reddit_2013_Topic15.0_anxiety,
# 5             Academic_2013_Topic1.0_scale,  Reddit_2013_Topic15.0_anxiety,
# 6             Academic_2013_Topic1.0_scale,  Reddit_2013_Topic15.0_anxiety,
# 7             Academic_2013_Topic1.0_scale,  Reddit_2013_Topic15.0_anxiety,
# ...

# %%
df6.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1193931
# 0.09999999999999998      32767
# softcosine                   1
# dtype: int64

# %%
df7=pd.read_csv("resj13_ga14.csv")
df7=df7.loc[:, ~df7.columns.str.contains('^Unnamed')]
df7
# Out:
#                                source1_label                   source2_label  \
# 0        Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# 1        Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# 2        Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# 3        Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# 4        Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# 5        Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# 6        Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# 7        Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# 8        Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# 9        Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# 10       Academic_2013_Topic26.0_depression,      Reddit_2014_Topic7.0_feel,
# ...

# %%
df7.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1343855
# 0.2                          2
# 0.09999999999999998      32765
# 0.2                          2
# softcosine                   1
# dtype: int64

# %%
df8=pd.read_csv("resj13_ga15.csv")
df8=df8.loc[:, ~df8.columns.str.contains('^Unnamed')]
df8
# Out:
#                            source1_label              source2_label  \
# 0          Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 1          Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 2          Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 3          Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 4          Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 5          Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 6          Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 7          Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 8          Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 9          Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 10         Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 11         Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# 12         Academic_2013_Topic40.0_risk,  Reddit_2015_Topic52.0_be,
# ...

# %%
df8.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1410815
# 0.09999999999999998      32767
# softcosine                   1
# dtype: int64

# %% [markdown]
# ### Academic 2014- Reddit (2012-2015)

# %%
df9=pd.read_csv("resj14_ga12.csv")
df9=df9.loc[:, ~df9.columns.str.contains('^Unnamed')]
df9
# Out:
#                             source1_label                  source2_label  \
# 0        Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 1        Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 2        Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 3        Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 4        Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 5        Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 6        Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 7        Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 8        Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 9        Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 10       Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# 11       Academic_2014_Topic29.0_anxiety,  Reddit_2012_Topic2.0_anxiety,
# ...

# %%
df9.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1270193
# 0.09999999999999998      32767
# softcosine                   1
# dtype: int64

# %%
df10=pd.read_csv("resj14_ga13.csv")
df10=df10.loc[:, ~df10.columns.str.contains('^Unnamed')]
df10
# Out:
#                               source1_label                   source2_label  \
# 0          Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# 1          Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# 2          Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# 3          Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# 4          Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# 5          Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# 6          Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# 7          Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# 8          Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# 9          Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# 10         Academic_2014_Topic29.0_anxiety,  Reddit_2013_Topic15.0_anxiety,
# ...

# %%
df10.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1075843
# 0.2                     119374
# 0.09999999999999998      15863
# 0.2                      16904
# softcosine                   1
# dtype: int64

# %%
df11=pd.read_csv("resj14_ga14.csv")
df11=df11.loc[:, ~df11.columns.str.contains('^Unnamed')]
df11
# Out:
#                             source1_label                   source2_label  \
# 0        Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 1        Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 2        Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 3        Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 4        Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 5        Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 6        Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 7        Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 8        Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 9        Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 10       Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 11       Academic_2014_Topic29.0_anxiety,      Reddit_2014_Topic7.0_feel,
# ...

# %%
df11.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1314016
# 0.2                      20837
# 0.09999999999999998      28010
# 0.2                       4757
# softcosine                   1
# dtype: int64

# %%
df12=pd.read_csv("resj14_ga15.csv")
df12=df12.loc[:, ~df12.columns.str.contains('^Unnamed')]
df12
# Out:
#                             source1_label                 source2_label  \
# 0          Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 1          Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 2          Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 3          Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 4          Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 5          Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 6          Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 7          Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 8          Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 9          Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 10         Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# 11         Academic_2014_Topic9.0_stress,     Reddit_2015_Topic52.0_be,
# ...

# %%
df12.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1408429
# 0.09999999999999998      32767
# softcosine                   1
# dtype: int64

# %% [markdown]
# ### Academic 2015 - Reddit (2012-2015)

# %%
df13=pd.read_csv("resj15_ga12.csv")
df13=df13.loc[:, ~df13.columns.str.contains('^Unnamed')]
df13
# Out:
#                             source1_label                  source2_label  \
# 0        Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 1        Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 2        Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 3        Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 4        Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 5        Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 6        Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 7        Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 8        Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 9        Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 10       Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# 11       Academic_2015_Topic14.0_symptom,  Reddit_2012_Topic2.0_anxiety,
# ...

# %%
df13.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1133489
# 0.09999999999999998      32767
# softcosine                   1
# dtype: int64

# %%
df14=pd.read_csv("resj15_ga13.csv")
df14=df14.loc[:, ~df14.columns.str.contains('^Unnamed')]
df14
# Out:
#                                  source1_label  \
# 0             Academic_2015_Topic15.0_anxiety,
# 1             Academic_2015_Topic15.0_anxiety,
# 2             Academic_2015_Topic15.0_anxiety,
# 3             Academic_2015_Topic15.0_anxiety,
# 4             Academic_2015_Topic15.0_anxiety,
# 5             Academic_2015_Topic15.0_anxiety,
# 6             Academic_2015_Topic15.0_anxiety,
# 7             Academic_2015_Topic15.0_anxiety,
# 8             Academic_2015_Topic15.0_anxiety,
# 9             Academic_2015_Topic15.0_anxiety,
# 10            Academic_2015_Topic15.0_anxiety,
# 11            Academic_2015_Topic15.0_anxiety,
# 12            Academic_2015_Topic15.0_anxiety,
# 13            Academic_2015_Topic15.0_anxiety,
# 14            Academic_2015_Topic15.0_anxiety,
# 15            Academic_2015_Topic15.0_anxiety,
# 16            Academic_2015_Topic15.0_anxiety,
# 17            Academic_2015_Topic15.0_anxiety,
# 18            Academic_2015_Topic15.0_anxiety,
# ...

# %%
df14.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1059753
# 0.09999999999999998      32767
# softcosine                   1
# dtype: int64

# %%
df15=pd.read_csv("resj15_ga14.csv")
df15=df15.loc[:, ~df15.columns.str.contains('^Unnamed')]
df15
# Out:
#                             source1_label                   source2_label  \
# 0        Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 1        Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 2        Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 3        Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 4        Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 5        Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 6        Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 7        Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 8        Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 9        Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 10       Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# 11       Academic_2015_Topic34.0_anxiety,      Reddit_2014_Topic7.0_feel,
# ...

# %%
df15.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1203271
# 0.09999999999999998      32767
# softcosine                   1
# dtype: int64

# %%
df16=pd.read_csv("resj15_ga15.csv")
df16=df16.loc[:, ~df16.columns.str.contains('^Unnamed')]
df16
# Out:
#                             source1_label                source2_label  \
# 0        Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 1        Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 2        Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 3        Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 4        Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 5        Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 6        Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 7        Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 8        Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 9        Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 10       Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# 11       Academic_2015_Topic34.0_anxiety,    Reddit_2015_Topic52.0_be,
# ...

# %%
df16.groupby('softcosine').size()
# Out:
# softcosine
# 0.09999999999999998    1245633
# 0.09999999999999998      32767
# softcosine                   1
# dtype: int64
