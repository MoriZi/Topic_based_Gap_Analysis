# %%
import pandas as pd

# %%
df1=pd.read_csv('/home/smriti/Desktop/NLP/MITACS/Anxiety/Data/CSV/BMCPsy.csv')

# %%
df2=pd.read_csv('/home/smriti/Desktop/NLP/MITACS/Anxiety/Data/CSV/BRT.csv')

# %%
df3=pd.read_csv('/home/smriti/Desktop/NLP/MITACS/Anxiety/Data/CSV/FiP.csv')

# %%
df4=pd.read_csv('/home/smriti/Desktop/NLP/MITACS/Anxiety/Data/CSV/Janx.csv')

# %%
df5=pd.read_csv('/home/smriti/Desktop/NLP/MITACS/Anxiety/Data/CSV/JoCC.csv')

# %%
df6=pd.read_csv('/home/smriti/Desktop/NLP/MITACS/Anxiety/Data/CSV/PsyM.csv')

# %%
frames=[df1,df2,df3,df4,df5,df6]
df=pd.concat(frames)
df.head()
# Out:
#                                                Title  \
# 0  Is preexisting mental illness associated with ...
# 1  "Mental health status among family members of ...
# 2  "Prevalence of problematic smartphone usage an...
# 3  The lifetime prevalence and impact of generali...
# 4  Mental health planning at a very early stage o...
#
#                                             Abstract     StoreId  \
# 0  Background: The purpose of this study was to e...  2493139215
# 1  Reports an error in "Mental health status amon...  2491974694
# 2  Reports an error in "Prevalence of problematic...  2490709965
# 3  Background: Generalized anxiety disorder (GAD)...  2490709900
# 4  Background: Mental health care systems have be...  2489749334
#
#                                         documentType  year
# 0   Journal , Peer Reviewed Journal , Journal Art...  2021
# 1   Journal , Peer Reviewed Journal , Erratum/Cor...  2021
# 2   Journal , Peer Reviewed Journal , Erratum/Cor...  2021
# ...

# %%
df11=df[df['year']==2011]
df11.head()
# Out:
#                                                  Title  \
# 660  Prevalence and risk factors of major depressiv...
# 661  Efficacy of exposure versus cognitive therapy ...
# 662  Seasonality in depressive and anxiety symptoms...
# 663  Healthcare utilization and costs in patients b...
# 664  General and specific components of depression ...
#
#                                               Abstract     StoreId  \
# 660  Background: Not much is known about the risk f...  1001921918
# 661  Background: There is growing evidence of the e...  1634755040
# 662  Background: Little is known about seasonality ...  1001919318
# 663  Background: Patterns of healthcare utilization...  1001923041
# 664  Background: Depressive and anxiety symptoms of...  1001919237
#
#                                           documentType  year
# 660   Journal , Peer Reviewed Journal , Journal Art...  2011
# 661   Journal , Peer Reviewed Journal , Journal Art...  2011
# ...

# %%
df11.to_csv("Acad2011.csv")

# %%
df12=df[df['year']==2012]
df12.head()
# Out:
#                                                  Title  \
# 615  Sleep quality and its psychological correlates...
# 616  The effectiveness of cognitive behavioral ther...
# 617  Psychometric properties of the Cardiac Depress...
# 618  Single-prolonged stress induces apoptosis in d...
# 619  Problem-solving versus cognitive restructuring...
#
#                                               Abstract     StoreId  \
# 615  Background: Sleep is an important physiologica...  1322257202
# 616  Background: Inflammatory Bowel Disease (IBD) p...  1640006791
# 617  Background: This study examined the psychometr...  1322258832
# 618  Introduction: Post-traumatic stress disorder (...  1640005981
# 619  Background: With an ageing population in most ...  1640006982
#
#                                           documentType  year
# 615   Journal , Peer Reviewed Journal , Journal Art...  2012
# 616   Journal , Peer Reviewed Journal , Journal Art...  2012
# ...

# %%
df12.shape
# Out:
# (379, 5)

# %%
df12.to_csv("Acad2012.csv")

# %%
df13=df[df['year']==2013]
df13.head()
# Out:
#                                                  Title  \
# 563  Preceding diagnoses to young adult bipolar dis...
# 564  Cost of anxiety disorders in Japan in 2008: A ...
# 565  Self-harm in young adolescents (12–16 years): ...
# 566  Patterns of risk for anxiety-depression amongs...
# 567  Functional social support, psychological capit...
#
#                                               Abstract     StoreId  \
# 563  Background: The aim of this comparative study ...  1511554824
# 564  Background: The societal burden caused by anxi...  1513356585
# 565  Background: To investigate the prevalence of s...  1513357265
# 566  Background: Studies suggest that immigrants ha...  1513356317
# 567  Background: Psychological distress (e.g., depr...  1513356330
#
#                                           documentType  year
# 563   Journal , Peer Reviewed Journal , Journal Art...  2013
# 564   Journal , Peer Reviewed Journal , Journal Art...  2013
# ...

# %%
df13.to_csv("Acad2013.csv")

# %%
df14=df[df['year']==2014]
df14.head()
# Out:
#                                                  Title  \
# 484  A randomized controlled trial of mental health...
# 485  Staff and service users’ views on a ‘Consent f...
# 486  Early risk factors for adult bipolar disorder ...
# 487  Comparison of psychiatric disability on the He...
# 488  A validation study of the Hospital Anxiety and...
#
#                                               Abstract     StoreId  \
# 484  Background: Experiencing systematic violence a...  1650982901
# 485  Background: Recruitment to mental health resea...  1650985265
# 486  Background: We aimed to outline the early risk...  1650983695
# 487  Background: Currently, the mental health issue...  1647030557
# 488  Background: The Hospital Anxiety and Depressio...  1647030599
#
#                                           documentType  year
# 484   Journal , Peer Reviewed Journal , Journal Art...  2014
# 485   Journal , Peer Reviewed Journal , Journal Art...  2014
# ...

# %%
df14.to_csv("Acad2014.csv")

# %%
df15=df[df['year']==2015]
df15.head()
# Out:
#                                                  Title  \
# 444  Anxiety and depression during pregnancy in Cen...
# 445  Changes in mental health in compliers and non-...
# 446  Psychiatric and neurological disorders in late...
# 447  Enthusiasm for homework and improvement of psy...
# 448  Cost-effectiveness of blended vs. Face-to-face...
#
#                                               Abstract     StoreId  \
# 444  Background: Around the world, maternal psychop...  1758380839
# 445  Background: There is a lack of research regard...  1758182902
# 446  Background: The relationship between mental il...  1756079990
# 447  Background: Cognitive behavioral therapy (CBT)...  1756079575
# 448  Background: Anxiety disorders are among the mo...  1753450094
#
#                                           documentType  year
# 444   Journal , Peer Reviewed Journal , Journal Art...  2015
# 445   Journal , Peer Reviewed Journal , Journal Art...  2015
# ...

# %%
df15.to_csv("Acad2015.csv")

# %%
df16=df[df['year']==2016]
df16.head()
# Out:
#                                                  Title  \
# 363  Mindsurf: A pilot study to assess the usabilit...
# 364   Psychiatrists’ experiences of suicide assessment
# 365  A pilot randomized controlled trial of a tailo...
# 366  "Validation of the Spanish version of the bord...
# 367  A comparative assessment of generalized anxiet...
#
#                                               Abstract     StoreId  \
# 363  Background: The Method of Levels (MOL) is a tr...  1854818852
# 364  Background: Clinical guidelines for suicide pr...  1853178311
# 365  Background: To examine the effectiveness and a...  1850192604
# 366  Reports an error in "Validation of the Spanish...  1850192075
# 367  Background: Data on mental health among orphan...  1828878359
#
#                                           documentType  year
# 363   Journal , Peer Reviewed Journal , Journal Art...  2016
# 364   Journal , Peer Reviewed Journal , Journal Art...  2016
# ...

# %%
df16.to_csv("Acad2016.csv")

# %%
df17=df[df['year']==2017]
df17.head()
# Out:
#                                                  Title  \
# 295  Readiness to change and therapy outcomes of an...
# 296  The influence of caregiver depression on adole...
# 297  German general practitioners’ self-reported ma...
# 298  Correlation of occupational stress with depres...
# 299  Anxiety and depression among patients with chr...
#
#                                               Abstract     StoreId  \
# 295  Background: Readiness to change is a pivotal c...  1989541468
# 296  Background: Family-level predictors, including...  1984308064
# 297  Background: Patients with chronic depression (...  1984307516
# 298  Background: This study aimed to investigate th...  1984307987
# 299  Background: Anxiety and depression are usually...  1984307861
#
#                                           documentType  year
# 295   Journal , Peer Reviewed Journal , Journal Art...  2017
# 296   Journal , Peer Reviewed Journal , Journal Art...  2017
# ...

# %%
df17.to_csv("Acad2017.csv")

# %%
df18=df[df['year']==2018]
df18.head()
# Out:
#                                                  Title  \
# 225  Perceptions of free will in obsessive-compulsi...
# 226  Validation of the Edinburgh Postnatal Depressi...
# 227  The impact of immigration detention on mental ...
# 228  Mental health outcomes among Arab refugees, im...
# 229  Preliminary evaluation of an intensive integra...
#
#                                               Abstract     StoreId  \
# 225  Background: The aim of this study was to explo...  2176956877
# 226  Background: The Edinburgh Postnatal Depression...  2179765653
# 227  Background: The number of asylum seekers, refu...  2183852388
# 228  Background: Arab refugees and immigrants livin...  2185898663
# 229  Background: To investigate the outcome of an i...  2165870767
#
#                                           documentType  year
# 225   Journal , Peer Reviewed Journal , Journal Art...  2018
# 226   Journal , Peer Reviewed Journal , Journal Art...  2018
# ...

# %%
df18.to_csv("Acad2018.csv")

# %%
df19=df[df['year']==2019]
df19.head()
# Out:
#                                                  Title  \
# 147  The impact of depression and anxiety treatment...
# 148  Implementation research for public sector ment...
# 149  Education level and risk of postpartum depress...
# 150  Cognitive behavioural therapy for the treatmen...
# 151  Child maltreatment, peer victimization, and so...
#
#                                               Abstract     StoreId  \
# 147  Background: Depressive and anxiety disorders h...  2348246166
# 148  Background: Mental disorders are a leading cau...  2350114559
# 149  Background: Lower socioeconomic status is ofte...  2348250946
# 150  Background: Late-life depression (LLD) is one ...  2348249459
# 151  Background: Childhood adversities, especially ...  2348244926
#
#                                           documentType  year
# 147   Journal , Peer Reviewed Journal , Journal Art...  2019
# 148   Journal , Peer Reviewed Journal , Journal Art...  2019
# ...

# %%
df19.to_csv("Acad2019.csv")

# %%
df20=df[df['year']==2020]
df20.head()
# Out:
#                                                 Title  \
# 15  A randomized controlled trial on the comparati...
# 16  Comparison of frontal alpha asymmetry among sc...
# 17  Mental health status of Chinese residents duri...
# 18  Low levels of soluble TWEAK, indicating on-goi...
# 19  Determinants of anxiety and depression in pati...
#
#                                              Abstract     StoreId  \
# 15  Background: The goal of this study was to inve...  2487173310
# 16  Background: Electroencephalography (EEG) front...  2487173474
# 17  Background: To investigate the mental health s...  2487172522
# 18  Background: Low levels of the soluble tumour n...  2487174465
# 19  Background: The aim of this cross-sectional st...  2486189768
#
#                                          documentType  year
# 15   Journal , Peer Reviewed Journal , Journal Art...  2020
# 16   Journal , Peer Reviewed Journal , Journal Art...  2020
# ...

# %%
df20.to_csv("Acad2020.csv")

# %%
df21=df[df['year']==2021]
df21.head()
# Out:
#                                                Title  \
# 0  Is preexisting mental illness associated with ...
# 1  "Mental health status among family members of ...
# 2  "Prevalence of problematic smartphone usage an...
# 3  The lifetime prevalence and impact of generali...
# 4  Mental health planning at a very early stage o...
#
#                                             Abstract     StoreId  \
# 0  Background: The purpose of this study was to e...  2493139215
# 1  Reports an error in "Mental health status amon...  2491974694
# 2  Reports an error in "Prevalence of problematic...  2490709965
# 3  Background: Generalized anxiety disorder (GAD)...  2490709900
# 4  Background: Mental health care systems have be...  2489749334
#
#                                         documentType  year
# 0   Journal , Peer Reviewed Journal , Journal Art...  2021
# 1   Journal , Peer Reviewed Journal , Erratum/Cor...  2021
# 2   Journal , Peer Reviewed Journal , Erratum/Cor...  2021
# ...

# %%
df21.to_csv("Acad2021.csv")
