# %%
import pandas as pd

# %%
df1=pd.read_csv("GA_j12r12.csv")
df1=df1.loc[:, ~df1.columns.str.contains('^Unnamed')]
df1.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2012       Reddit        2012
# 1  Academic         2012       Reddit        2012
# 2  Academic         2012       Reddit        2012
# 3  Academic         2012       Reddit        2012
# 4  Academic         2012       Reddit        2012
#
#                                                query  query_topicID  \
# 0  ['round', 'willing', 'connect', 'please', 'reg...              0
# 1  ['acceptance', 'cognitive_behavioral', 'key', ...              1
# 2  ['anxiety', 'feel', 'go', 'be', 'get', 'have',...              2
# 3  ['drive', 'cop', 'mile', 'gas', 'driving', 'un...              3
# 4  ['be', 'people', 'want', 'know', 'think', 'say...              4
#
#                                           best_match  best_match_score  \
# 0  ['fear', 'sad', 'memory', 'social', 'previous'...          0.593930
# 1  ['social', 'participant', 'positive', 'anxiety...          0.659234
# 2  ['anxiety', 'guide', 'find', 'face', 'scale', ...          0.826772
# 3  ['sleep', 'hybrid', 'monitoring', 'insomnia', ...          0.559757
# 4  ['fear', 'sad', 'memory', 'social', 'previous'...          0.676318
#
#    best_match_topicID
# 0                  18
# 1                   5
# 2                  24
# 3                   1
# 4                  18

# %%
df2=pd.read_csv("GA_j12r13.csv")
df2=df2.loc[:, ~df2.columns.str.contains('^Unnamed')]
df2.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2012       Reddit        2013
# 1  Academic         2012       Reddit        2013
# 2  Academic         2012       Reddit        2013
# 3  Academic         2012       Reddit        2013
# 4  Academic         2012       Reddit        2013
#
#                                                query  query_topicID  \
# 0  ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 1  ['ahead', 'hardest', 'butt', 'upside', 'thrill...              1
# 2  ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 3  ['kind', 'big', 'hit', 'tired', 'wake', 'aweso...              3
# 4  ['testing', 'genre', 'flare', 'upside', 'thril...              4
#
#                                           best_match  best_match_score  \
# 0  ['factor', 'model', 'domain', 'structure', 'de...          0.510060
# 1  ['single', 'nucleus', 'rat', 'apoptosis', 'neu...          0.558444
# 2  ['factor', 'model', 'domain', 'structure', 'de...          0.510060
# 3  ['patient', 'anxiety', 'cognitive', 'treatment...          0.601308
# 4  ['anxiety', 'guide', 'find', 'face', 'scale', ...          0.509972
#
#    best_match_topicID
# 0                  19
# 1                  32
# 2                  19
# 3                   8
# 4                  24

# %%
df3=pd.read_csv("GA_j12r14.csv")
df3=df3.loc[:, ~df3.columns.str.contains('^Unnamed')]
df3.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2012       Reddit        2014
# 1  Academic         2012       Reddit        2014
# 2  Academic         2012       Reddit        2014
# 3  Academic         2012       Reddit        2014
# 4  Academic         2012       Reddit        2014
#
#                                                query  query_topicID  \
# 0  ['room', 'mother', 'treat', 'exactly', 'strang...              0
# 1  ['circus', 'waist', 'battery', 'appearance', '...              1
# 2  ['circus', 'waist', 'battery', 'appearance', '...              1
# 3  ['depression', 'tonight', 'suffer', 'anxiety',...              3
# 4  ['anxiety', 'remember', 'try', 'see', 'year', ...              4
#
#                                           best_match  best_match_score  \
# 0  ['child', 'anxiety', 'disorder', 'parent', 'no...          0.709107
# 1  ['fear', 'sad', 'memory', 'social', 'previous'...          0.540187
# 2  ['fear', 'sad', 'memory', 'social', 'previous'...          0.540187
# 3  ['mood', 'disorder', 'depressive', 'depressed'...          0.842015
# 4  ['anxiety', 'guide', 'find', 'face', 'scale', ...          0.791164
#
#    best_match_topicID
# 0                  36
# 1                  18
# 2                  18
# 3                   2
# 4                  24

# %%
df4=pd.read_csv("GA_j12r15.csv")
df4=df4.loc[:, ~df4.columns.str.contains('^Unnamed')]
df4.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2012       Reddit        2015
# 1  Academic         2012       Reddit        2015
# 2  Academic         2012       Reddit        2015
# 3  Academic         2012       Reddit        2015
# 4  Academic         2012       Reddit        2015
#
#                                                query  query_topicID  \
# 0  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 1  ['play', 'online', 'game', 'name', 'email', 'd...              1
# 2  ['simple', 'glad', 'accept', 'reality', 'one',...              2
# 3  ['red', 'letter', 'mail', 'advice', 'may', 'di...              3
# 4  ['effect', 'beat', 'option', 'frequently', 'li...              4
#
#                                           best_match  best_match_score  \
# 0  ['fear', 'sad', 'memory', 'social', 'previous'...          0.605787
# 1  ['fear', 'sad', 'memory', 'social', 'previous'...          0.652642
# 2  ['fear', 'sad', 'memory', 'social', 'previous'...          0.624482
# 3  ['fear', 'sad', 'memory', 'social', 'previous'...          0.708107
# 4  ['effect', 'participant', 'complete', 'act', '...          0.638938
#
#    best_match_topicID
# 0                  18
# 1                  18
# 2                  18
# 3                  18
# 4                   6

# %%
df5=pd.read_csv("GA_j13r12.csv")
df5=df5.loc[:, ~df5.columns.str.contains('^Unnamed')]
df5.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2013       Reddit        2012
# 1  Academic         2013       Reddit        2012
# 2  Academic         2013       Reddit        2012
# 3  Academic         2013       Reddit        2012
# 4  Academic         2013       Reddit        2012
#
#                                                query  query_topicID  \
# 0  ['round', 'willing', 'connect', 'please', 'reg...              0
# 1  ['acceptance', 'cognitive_behavioral', 'key', ...              1
# 2  ['anxiety', 'feel', 'go', 'be', 'get', 'have',...              2
# 3  ['drive', 'cop', 'mile', 'gas', 'driving', 'un...              3
# 4  ['be', 'people', 'want', 'know', 'think', 'say...              4
#
#                                           best_match  best_match_score  \
# 0  ['attention', 'activation', 'image', 'face', '...          0.586604
# 1  ['social', 'internalize', 'anxiety', 'subject'...          0.660874
# 2  ['anxiety', 'associate', 'self', 'risk', 'high...          0.829521
# 3  ['abuse', 'must', 'sexual', 'human', 'return',...          0.534181
# 4  ['attention', 'activation', 'image', 'face', '...          0.615116
#
#    best_match_topicID
# 0                  27
# 1                   1
# 2                   2
# 3                  25
# 4                  27

# %%
df6=pd.read_csv("GA_j13r13.csv")
df6=df6.loc[:, ~df6.columns.str.contains('^Unnamed')]
df6.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2013       Reddit        2013
# 1  Academic         2013       Reddit        2013
# 2  Academic         2013       Reddit        2013
# 3  Academic         2013       Reddit        2013
# 4  Academic         2013       Reddit        2013
#
#                                                query  query_topicID  \
# 0  ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 1  ['ahead', 'hardest', 'butt', 'upside', 'thrill...              1
# 2  ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 3  ['kind', 'big', 'hit', 'tired', 'wake', 'aweso...              3
# 4  ['testing', 'genre', 'flare', 'upside', 'thril...              4
#
#                                           best_match  best_match_score  \
# 0  ['symptom', 'function', 'member', 'specific', ...          0.522782
# 1  ['depression', 'cognitive', 'risk', 'woman', '...          0.546241
# 2  ['symptom', 'function', 'member', 'specific', ...          0.522782
# 3  ['strongly', 'pool', 'behaviour', 'single', 'l...          0.633819
# 4  ['distress', 'scale', 'factor', 'screening', '...          0.516897
#
#    best_match_topicID
# 0                  48
# 1                   4
# 2                  48
# 3                  38
# 4                  49

# %%
df7=pd.read_csv("GA_j13r14.csv")
df7=df7.loc[:, ~df7.columns.str.contains('^Unnamed')]
df7.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2013       Reddit        2014
# 1  Academic         2013       Reddit        2014
# 2  Academic         2013       Reddit        2014
# 3  Academic         2013       Reddit        2014
# 4  Academic         2013       Reddit        2014
#
#                                                query  query_topicID  \
# 0  ['room', 'mother', 'treat', 'exactly', 'strang...              0
# 1  ['circus', 'waist', 'battery', 'appearance', '...              1
# 2  ['circus', 'waist', 'battery', 'appearance', '...              1
# 3  ['depression', 'tonight', 'suffer', 'anxiety',...              3
# 4  ['anxiety', 'remember', 'try', 'see', 'year', ...              4
#
#                                           best_match  best_match_score  \
# 0  ['child', 'anxiety', 'treatment', 'parent', 'r...          0.683643
# 1  ['strongly', 'pool', 'behaviour', 'single', 'l...          0.610831
# 2  ['strongly', 'pool', 'behaviour', 'single', 'l...          0.610831
# 3  ['depressive', 'system', 'major', 'depressed',...          0.754244
# 4  ['anxiety', 'associate', 'self', 'risk', 'high...          0.760344
#
#    best_match_topicID
# 0                  34
# 1                  38
# 2                  38
# 3                  29
# 4                   2

# %%
df8=pd.read_csv("GA_j13r15.csv")
df8=df8.loc[:, ~df8.columns.str.contains('^Unnamed')]
df8.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2013       Reddit        2015
# 1  Academic         2013       Reddit        2015
# 2  Academic         2013       Reddit        2015
# 3  Academic         2013       Reddit        2015
# 4  Academic         2013       Reddit        2015
#
#                                                query  query_topicID  \
# 0  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 1  ['play', 'online', 'game', 'name', 'email', 'd...              1
# 2  ['simple', 'glad', 'accept', 'reality', 'one',...              2
# 3  ['red', 'letter', 'mail', 'advice', 'may', 'di...              3
# 4  ['effect', 'beat', 'option', 'frequently', 'li...              4
#
#                                           best_match  best_match_score  \
# 0  ['symptom', 'function', 'member', 'specific', ...          0.651500
# 1  ['social', 'internalize', 'anxiety', 'subject'...          0.607789
# 2  ['social', 'internalize', 'anxiety', 'subject'...          0.648781
# 3  ['social', 'internalize', 'anxiety', 'subject'...          0.684816
# 4  ['strongly', 'pool', 'behaviour', 'single', 'l...          0.626112
#
#    best_match_topicID
# 0                  48
# 1                   1
# 2                   1
# 3                   1
# 4                  38

# %%
df9=pd.read_csv("GA_j14r12.csv")
df9=df9.loc[:, ~df9.columns.str.contains('^Unnamed')]
df9.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2014       Reddit        2012
# 1  Academic         2014       Reddit        2012
# 2  Academic         2014       Reddit        2012
# 3  Academic         2014       Reddit        2012
# 4  Academic         2014       Reddit        2012
#
#                                                query  query_topicID  \
# 0  ['round', 'willing', 'connect', 'please', 'reg...              0
# 1  ['acceptance', 'cognitive_behavioral', 'key', ...              1
# 2  ['anxiety', 'feel', 'go', 'be', 'get', 'have',...              2
# 3  ['drive', 'cop', 'mile', 'gas', 'driving', 'un...              3
# 4  ['be', 'people', 'want', 'know', 'think', 'say...              4
#
#                                           best_match  best_match_score  \
# 0  ['worry', 'deliver', 'telephone', 'clinician',...          0.620435
# 1  ['psychotherapy', 'intent', 'cancer', 'benefic...          0.612476
# 2  ['anxiety', 'prevalence', 'increase', 'physica...          0.773832
# 3  ['impairment', 'life', 'quality', 'domain', 'e...          0.567577
# 4  ['attention', 'task', 'mindfulness', 'focus', ...          0.594252
#
#    best_match_topicID
# 0                  45
# 1                  55
# 2                  33
# 3                  39
# 4                  32

# %%
df10=pd.read_csv("GA_j14r13.csv")
df10=df10.loc[:, ~df10.columns.str.contains('^Unnamed')]
df10.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2014       Reddit        2013
# 1  Academic         2014       Reddit        2013
# 2  Academic         2014       Reddit        2013
# 3  Academic         2014       Reddit        2013
# 4  Academic         2014       Reddit        2013
#
#                                                query  query_topicID  \
# 0  ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 1  ['ahead', 'hardest', 'butt', 'upside', 'thrill...              1
# 2  ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 3  ['kind', 'big', 'hit', 'tired', 'wake', 'aweso...              3
# 4  ['testing', 'genre', 'flare', 'upside', 'thril...              4
#
#                                           best_match  best_match_score  \
# 0  ['marker', 'single', 'mental', 'health', 'esti...          0.535360
# 1  ['marker', 'single', 'mental', 'health', 'esti...          0.578372
# 2  ['marker', 'single', 'mental', 'health', 'esti...          0.535360
# 3  ['impairment', 'life', 'quality', 'domain', 'e...          0.650309
# 4  ['symptom', 'sample', 'clinical', 'dimension',...          0.561690
#
#    best_match_topicID
# 0                   2
# 1                   2
# 2                   2
# 3                  39
# 4                  15

# %%
df11=pd.read_csv("GA_j14r14.csv")
df11=df11.loc[:, ~df11.columns.str.contains('^Unnamed')]
df11.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2014       Reddit        2014
# 1  Academic         2014       Reddit        2014
# 2  Academic         2014       Reddit        2014
# 3  Academic         2014       Reddit        2014
# 4  Academic         2014       Reddit        2014
#
#                                                query  query_topicID  \
# 0  ['room', 'mother', 'treat', 'exactly', 'strang...              0
# 1  ['circus', 'waist', 'battery', 'appearance', '...              1
# 2  ['circus', 'waist', 'battery', 'appearance', '...              1
# 3  ['depression', 'tonight', 'suffer', 'anxiety',...              3
# 4  ['anxiety', 'remember', 'try', 'see', 'year', ...              4
#
#                                           best_match  best_match_score  \
# 0  ['child', 'parent', 'family', 'maintain', 'pro...          0.687474
# 1  ['disorder', 'anxiety', 'admixture', 'characte...          0.542502
# 2  ['disorder', 'anxiety', 'admixture', 'characte...          0.542502
# 3  ['depressive', 'anxious', 'non', 'mdd', 'major...          0.802596
# 4  ['anxiety', 'prevalence', 'increase', 'physica...          0.737327
#
#    best_match_topicID
# 0                  29
# 1                  28
# 2                  28
# 3                  52
# 4                  33

# %%
df12=pd.read_csv("GA_j14r15.csv")
df12=df12.loc[:, ~df12.columns.str.contains('^Unnamed')]
df12.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2014       Reddit        2015
# 1  Academic         2014       Reddit        2015
# 2  Academic         2014       Reddit        2015
# 3  Academic         2014       Reddit        2015
# 4  Academic         2014       Reddit        2015
#
#                                                query  query_topicID  \
# 0  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 1  ['play', 'online', 'game', 'name', 'email', 'd...              1
# 2  ['simple', 'glad', 'accept', 'reality', 'one',...              2
# 3  ['red', 'letter', 'mail', 'advice', 'may', 'di...              3
# 4  ['effect', 'beat', 'option', 'frequently', 'li...              4
#
#                                           best_match  best_match_score  \
# 0  ['onset', 'administer', 'analysis', 'number', ...          0.641321
# 1  ['onset', 'administer', 'analysis', 'number', ...          0.615899
# 2  ['dimension', 'value', 'individual', 'examine'...          0.623561
# 3  ['worry', 'deliver', 'telephone', 'clinician',...          0.691874
# 4  ['discriminant', 'validity', 'measure', 'facto...          0.627677
#
#    best_match_topicID
# 0                  51
# 1                  51
# 2                  41
# 3                  45
# 4                  14

# %%
df13=pd.read_csv("GA_j15r12.csv")
df13=df13.loc[:, ~df13.columns.str.contains('^Unnamed')]
df13.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2015       Reddit        2012
# 1  Academic         2015       Reddit        2012
# 2  Academic         2015       Reddit        2012
# 3  Academic         2015       Reddit        2012
# 4  Academic         2015       Reddit        2012
#
#                                                query  query_topicID  \
# 0  ['round', 'willing', 'connect', 'please', 'reg...              0
# 1  ['acceptance', 'cognitive_behavioral', 'key', ...              1
# 2  ['anxiety', 'feel', 'go', 'be', 'get', 'have',...              2
# 3  ['drive', 'cop', 'mile', 'gas', 'driving', 'un...              3
# 4  ['be', 'people', 'want', 'know', 'think', 'say...              4
#
#                                           best_match  best_match_score  \
# 0  ['attention', 'threat', 'child', 'task', 'css'...          0.588987
# 1  ['personality', 'prospective', 'cocaine', 'pre...          0.613174
# 2  ['anxiety', 'response', 'function', 'high', 'c...          0.832934
# 3  ['high', 'function', 'low', 'predict', 'disord...          0.554758
# 4  ['emotional', 'task', 'person', 'modify', 'att...          0.610386
#
#    best_match_topicID
# 0                  19
# 1                  20
# 2                  50
# 3                  16
# 4                  23

# %%
df14=pd.read_csv("GA_j15r13.csv")
df14=df14.loc[:, ~df14.columns.str.contains('^Unnamed')]
df14.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2015       Reddit        2013
# 1  Academic         2015       Reddit        2013
# 2  Academic         2015       Reddit        2013
# 3  Academic         2015       Reddit        2013
# 4  Academic         2015       Reddit        2013
#
#                                                query  query_topicID  \
# 0  ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 1  ['ahead', 'hardest', 'butt', 'upside', 'thrill...              1
# 2  ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 3  ['kind', 'big', 'hit', 'tired', 'wake', 'aweso...              3
# 4  ['testing', 'genre', 'flare', 'upside', 'thril...              4
#
#                                           best_match  best_match_score  \
# 0  ['database', 'patient', 'suicidal', 'receive',...          0.560626
# 1  ['database', 'patient', 'suicidal', 'receive',...          0.596992
# 2  ['database', 'patient', 'suicidal', 'receive',...          0.560626
# 3  ['economic', 'burden', 'face', 'therapy', 'cal...          0.669887
# 4  ['symptom', 'self', 'panic', 'patient', 'clini...          0.554218
#
#    best_match_topicID
# 0                  46
# 1                  46
# 2                  46
# 3                  72
# 4                  42

# %%
df15=pd.read_csv("GA_j15r14.csv")
df15=df15.loc[:, ~df15.columns.str.contains('^Unnamed')]
df15.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2015       Reddit        2014
# 1  Academic         2015       Reddit        2014
# 2  Academic         2015       Reddit        2014
# 3  Academic         2015       Reddit        2014
# 4  Academic         2015       Reddit        2014
#
#                                                query  query_topicID  \
# 0  ['room', 'mother', 'treat', 'exactly', 'strang...              0
# 1  ['circus', 'waist', 'battery', 'appearance', '...              1
# 2  ['circus', 'waist', 'battery', 'appearance', '...              1
# 3  ['depression', 'tonight', 'suffer', 'anxiety',...              3
# 4  ['anxiety', 'remember', 'try', 'see', 'year', ...              4
#
#                                           best_match  best_match_score  \
# 0  ['mother', 'pregnancy', 'symptom', 'depression...          0.693422
# 1  ['dimensional', 'dropout', 'contrast', 'predic...          0.552216
# 2  ['dimensional', 'dropout', 'contrast', 'predic...          0.552216
# 3  ['anxiety', 'child', 'disorder', 'clinical', '...          0.750780
# 4  ['style', 'treatment', 'subsample', 'anxiety',...          0.732447
#
#    best_match_topicID
# 0                  60
# 1                  70
# 2                  70
# 3                  69
# 4                  15

# %%
df16=pd.read_csv("GA_j15r15.csv")
df16=df16.loc[:, ~df16.columns.str.contains('^Unnamed')]
df16.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2015       Reddit        2015
# 1  Academic         2015       Reddit        2015
# 2  Academic         2015       Reddit        2015
# 3  Academic         2015       Reddit        2015
# 4  Academic         2015       Reddit        2015
#
#                                                query  query_topicID  \
# 0  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 1  ['play', 'online', 'game', 'name', 'email', 'd...              1
# 2  ['simple', 'glad', 'accept', 'reality', 'one',...              2
# 3  ['red', 'letter', 'mail', 'advice', 'may', 'di...              3
# 4  ['effect', 'beat', 'option', 'frequently', 'li...              4
#
#                                           best_match  best_match_score  \
# 0  ['emotional', 'task', 'person', 'modify', 'att...          0.615702
# 1  ['internet', 'intervention', 'mediation', 'val...          0.585048
# 2  ['emotional', 'task', 'person', 'modify', 'att...          0.650755
# 3  ['internet', 'intervention', 'mediation', 'val...          0.670636
# 4  ['immediately', 'act', 'heart', 'wave', 'hold'...          0.652418
#
#    best_match_topicID
# 0                  23
# 1                  51
# 2                  23
# 3                  51
# 4                  76

# %%
ls=[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16]
df=pd.concat(ls)
df.head()
# Out:
#      corpus  corpus_year query_source  query_year  \
# 0  Academic         2012       Reddit        2012
# 1  Academic         2012       Reddit        2012
# 2  Academic         2012       Reddit        2012
# 3  Academic         2012       Reddit        2012
# 4  Academic         2012       Reddit        2012
#
#                                                query  query_topicID  \
# 0  ['round', 'willing', 'connect', 'please', 'reg...              0
# 1  ['acceptance', 'cognitive_behavioral', 'key', ...              1
# 2  ['anxiety', 'feel', 'go', 'be', 'get', 'have',...              2
# 3  ['drive', 'cop', 'mile', 'gas', 'driving', 'un...              3
# 4  ['be', 'people', 'want', 'know', 'think', 'say...              4
#
#                                           best_match  best_match_score  \
# 0  ['fear', 'sad', 'memory', 'social', 'previous'...          0.593930
# 1  ['social', 'participant', 'positive', 'anxiety...          0.659234
# 2  ['anxiety', 'guide', 'find', 'face', 'scale', ...          0.826772
# 3  ['sleep', 'hybrid', 'monitoring', 'insomnia', ...          0.559757
# 4  ['fear', 'sad', 'memory', 'social', 'previous'...          0.676318
#
#    best_match_topicID
# 0                  18
# 1                   5
# 2                  24
# 3                   1
# 4                  18

# %%
df.shape
# Out:
# (808, 9)

# %%
df
# Out:
#       corpus  corpus_year query_source  query_year  \
# 0   Academic         2012       Reddit        2012
# 1   Academic         2012       Reddit        2012
# 2   Academic         2012       Reddit        2012
# 3   Academic         2012       Reddit        2012
# 4   Academic         2012       Reddit        2012
# 5   Academic         2012       Reddit        2012
# 6   Academic         2012       Reddit        2012
# 7   Academic         2012       Reddit        2012
# 8   Academic         2012       Reddit        2012
# 9   Academic         2012       Reddit        2012
# 0   Academic         2012       Reddit        2013
# 1   Academic         2012       Reddit        2013
# 2   Academic         2012       Reddit        2013
# 3   Academic         2012       Reddit        2013
# 4   Academic         2012       Reddit        2013
# 5   Academic         2012       Reddit        2013
# 6   Academic         2012       Reddit        2013
# 7   Academic         2012       Reddit        2013
# 8   Academic         2012       Reddit        2013
# 9   Academic         2012       Reddit        2013
# 10  Academic         2012       Reddit        2013
# 11  Academic         2012       Reddit        2013
# 12  Academic         2012       Reddit        2013
# 13  Academic         2012       Reddit        2013
# 14  Academic         2012       Reddit        2013
# 15  Academic         2012       Reddit        2013
# 16  Academic         2012       Reddit        2013
# 17  Academic         2012       Reddit        2013
# 18  Academic         2012       Reddit        2013
# 19  Academic         2012       Reddit        2013
# ..       ...          ...          ...         ...
# 40  Academic         2015       Reddit        2015
# 41  Academic         2015       Reddit        2015
# 42  Academic         2015       Reddit        2015
# 43  Academic         2015       Reddit        2015
# 44  Academic         2015       Reddit        2015
# 45  Academic         2015       Reddit        2015
# 46  Academic         2015       Reddit        2015
# 47  Academic         2015       Reddit        2015
# 48  Academic         2015       Reddit        2015
# 49  Academic         2015       Reddit        2015
# 50  Academic         2015       Reddit        2015
# 51  Academic         2015       Reddit        2015
# 52  Academic         2015       Reddit        2015
# 53  Academic         2015       Reddit        2015
# 54  Academic         2015       Reddit        2015
# 55  Academic         2015       Reddit        2015
# 56  Academic         2015       Reddit        2015
# 57  Academic         2015       Reddit        2015
# 58  Academic         2015       Reddit        2015
# 59  Academic         2015       Reddit        2015
# 60  Academic         2015       Reddit        2015
# 61  Academic         2015       Reddit        2015
# 62  Academic         2015       Reddit        2015
# 63  Academic         2015       Reddit        2015
# 64  Academic         2015       Reddit        2015
# 65  Academic         2015       Reddit        2015
# 66  Academic         2015       Reddit        2015
# 67  Academic         2015       Reddit        2015
# 68  Academic         2015       Reddit        2015
# 69  Academic         2015       Reddit        2015
#
#                                                 query  query_topicID  \
# 0   ['round', 'willing', 'connect', 'please', 'reg...              0
# 1   ['acceptance', 'cognitive_behavioral', 'key', ...              1
# 2   ['anxiety', 'feel', 'go', 'be', 'get', 'have',...              2
# 3   ['drive', 'cop', 'mile', 'gas', 'driving', 'un...              3
# 4   ['be', 'people', 'want', 'know', 'think', 'say...              4
# 5   ['relax', 'silly', 'large', 'male', 'psycholog...              5
# 6   ['breath', 'breathe', 'breathing', 'absolutely...              6
# 7   ['create', 'goal', 'amount', 'coffee', 'quit',...              7
# 8   ['sound', 'roll', 'chat', 'window', 'intereste...              8
# 9   ['visit', 'event', 'reward', 'roommate', 'cowo...              9
# 0   ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 1   ['ahead', 'hardest', 'butt', 'upside', 'thrill...              1
# 2   ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 3   ['kind', 'big', 'hit', 'tired', 'wake', 'aweso...              3
# 4   ['testing', 'genre', 'flare', 'upside', 'thril...              4
# 5   ['little', 'do', 'feeling', 'level', 'state', ...              5
# 6   ['laugh', 'shirt', 'stigmata', 'summary', 'sel...              6
# 7   ['people', 'help', 'make', 'life', 'would', 'w...              7
# 8   ['example', 'quite', 'bus', 'asshole', 'bit', ...              8
# 9   ['whenever', 'word', 'negative', 'quickly', 'm...              9
# 10  ['class', 'symptom', 'room', 'girl', 'kill', '...             10
# 11  ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 12  ['phone', 'pm', 'alarm', 'set', 'upside', 'sum...             12
# 13  ['funny', 'article', 'regard', 'smart', 'hopef...             13
# 14  ['create', 'link', 'research', 'information', ...             14
# 15  ['anxiety', 'feel', 'get', 'go', 'have', 'time...             15
# 16  ['far', 'common', 'mine', 'overwhelming', 'con...             16
# 17  ['genre', 'flare', 'upside', 'thriller', 'summ...              0
# 18  ['send', 'generalize', 'meal', 'stigmata', 'up...             18
# 19  ['insurance', 'victory', 'cover', 'private', '...             19
# ..                                                ...            ...
# 40  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 41  ['brain', 'subreddit', 'feel', 'fix', 'mistake...             41
# 42  ['heart', 'breath', 'chest', 'deep', 'player',...             42
# 43  ['finally', 'incredibly', 'drug', 'help', 'apo...             43
# 44  ['free', 'post', 'helpful', 'weekend', 'view',...             44
# 45  ['college', 'student', 'wide', 'mentality', 'c...             45
# 46  ['relate', 'learn', 'slowly', 'light', 'uncomf...             46
# 47  ['tend', 'entirely', 'wherever', 'plummet', 'n...             47
# 48  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 49  ['would', 'say', 'could', 'give', 'start', 'st...             49
# 50  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 51  ['effort', 'decrease', 'news', 'read', 'negati...             51
# 52  ['be', 'anxiety', 'feel', 'go', 'get', 'make',...             52
# 53  ['parent', 'plummet', 'damaging', 'numerous', ...             53
# 54  ['experience', 'appointment', 'type', 'class',...             54
# 55  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 56  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 57  ['money', 'tip', 'reduce', 'yell', 'stomach', ...             57
# 58  ['job', 'interview', 'lack', 'badly', 'positio...             58
# 59  ['sweat', 'psychologist', 'awake', 'shake', 'w...             59
# 60  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 61  ['body', 'blood', 'neck', 'somewhere', 'ready'...             61
# 62  ['shop', 'severely', 'tackle', 'buy', 'inside'...             62
# 63  ['live', 'can', 'sometimes', 'be', 'fucking', ...             63
# 64  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 65  ['close', 'dark', 'fully', 'common', 'lead', '...             65
# 66  ['symptom', 'suppose', 'respond', 'amount', 's...             66
# 67  ['fuck', 'city', 'edge', 'useless', 'square', ...             67
# 68  ['plummet', 'damaging', 'numerous', 'frighteni...              0
# 69  ['dumb', 'round', 'wherever', 'peeve', 'numero...             69
#
#                                            best_match  best_match_score  \
# 0   ['fear', 'sad', 'memory', 'social', 'previous'...          0.593930
# 1   ['social', 'participant', 'positive', 'anxiety...          0.659234
# 2   ['anxiety', 'guide', 'find', 'face', 'scale', ...          0.826772
# 3   ['sleep', 'hybrid', 'monitoring', 'insomnia', ...          0.559757
# 4   ['fear', 'sad', 'memory', 'social', 'previous'...          0.676318
# 5   ['anxiety', 'guide', 'find', 'face', 'scale', ...          0.657610
# 6   ['self', 'remission', 'depression', 'anxiety',...          0.591784
# 7   ['fear', 'sad', 'memory', 'social', 'previous'...          0.685357
# 8   ['symptom', 'patient', 'depression', 'somatic'...          0.575883
# 9   ['child', 'anxiety', 'disorder', 'parent', 'no...          0.629698
# 0   ['factor', 'model', 'domain', 'structure', 'de...          0.510060
# 1   ['single', 'nucleus', 'rat', 'apoptosis', 'neu...          0.558444
# 2   ['factor', 'model', 'domain', 'structure', 'de...          0.510060
# 3   ['patient', 'anxiety', 'cognitive', 'treatment...          0.601308
# 4   ['anxiety', 'guide', 'find', 'face', 'scale', ...          0.509972
# 5   ['fear', 'sad', 'memory', 'social', 'previous'...          0.613544
# 6   ['ptsd', 'trauma', 'alcohol', 'perceive', 'sta...          0.513818
# 7   ['anxiety', 'guide', 'find', 'face', 'scale', ...          0.720100
# 8   ['factor', 'model', 'domain', 'structure', 'de...          0.593318
# 9   ['mdd', 'patient', 'generalize', 'disorder', '...          0.568085
# 10  ['anxiety', 'measure', 'low', 'class', 'high',...          0.637083
# 11  ['factor', 'model', 'domain', 'structure', 'de...          0.510060
# 12  ['self', 'social', 'symptom', 'report', 'predi...          0.602174
# 13  ['self', 'social', 'symptom', 'report', 'predi...          0.547683
# 14  ['fear', 'sad', 'memory', 'social', 'previous'...          0.629145
# 15  ['anxiety', 'guide', 'find', 'face', 'scale', ...          0.777106
# 16  ['anxiety', 'guide', 'find', 'face', 'scale', ...          0.686743
# 17  ['factor', 'model', 'domain', 'structure', 'de...          0.510060
# 18  ['ptsd', 'trauma', 'alcohol', 'perceive', 'sta...          0.552910
# 19  ['risk', 'early', 'intervention', 'moderator',...          0.621018
# ..                                                ...               ...
# 40  ['emotional', 'task', 'person', 'modify', 'att...          0.615702
# 41  ['emotional', 'task', 'person', 'modify', 'att...          0.621009
# 42  ['anxiety', 'response', 'function', 'high', 'c...          0.701192
# 43  ['hypothesise', 'treatment', 'outcome', 'patie...          0.724719
# 44  ['mood', 'week', 'prenatal', 'postpartum', 'em...          0.604179
# 45  ['training', 'bias', 'anxious', 'train', 'chil...          0.578885
# 46  ['subjective', 'visual', 'skin', 'extinction_l...          0.619063
# 47  ['internet', 'intervention', 'mediation', 'val...          0.618633
# 48  ['emotional', 'task', 'person', 'modify', 'att...          0.615702
# 49  ['immediately', 'act', 'heart', 'wave', 'hold'...          0.578700
# 50  ['emotional', 'task', 'person', 'modify', 'att...          0.615702
# 51  ['emotional', 'task', 'person', 'modify', 'att...          0.707216
# 52  ['anxiety', 'response', 'function', 'high', 'c...          0.790124
# 53  ['attention', 'threat', 'child', 'task', 'css'...          0.665987
# 54  ['emotion', 'mind', 'situation', 'training', '...          0.712252
# 55  ['emotional', 'task', 'person', 'modify', 'att...          0.615702
# 56  ['emotional', 'task', 'person', 'modify', 'att...          0.615702
# 57  ['economic', 'burden', 'face', 'therapy', 'cal...          0.633935
# 58  ['subjective', 'visual', 'skin', 'extinction_l...          0.644763
# 59  ['health', 'stroke', 'sleep', 'caregiver', 'im...          0.709535
# 60  ['emotional', 'task', 'person', 'modify', 'att...          0.615702
# 61  ['degree', 'day', 'control', 'anxiety', 'patie...          0.642321
# 62  ['emotional', 'task', 'person', 'modify', 'att...          0.546962
# 63  ['genetic', 'additional', 'event', 'moreover',...          0.613624
# 64  ['emotional', 'task', 'person', 'modify', 'att...          0.615702
# 65  ['high', 'function', 'low', 'predict', 'disord...          0.611146
# 66  ['symptom', 'self', 'panic', 'patient', 'clini...          0.697104
# 67  ['dimensional', 'dropout', 'contrast', 'predic...          0.575313
# 68  ['emotional', 'task', 'person', 'modify', 'att...          0.615702
# 69  ['internet', 'intervention', 'mediation', 'val...          0.636295
#
#     best_match_topicID
# 0                   18
# 1                    5
# 2                   24
# 3                    1
# 4                   18
# 5                   24
# 6                   11
# 7                   18
# 8                   37
# 9                   36
# 0                   19
# 1                   32
# 2                   19
# 3                    8
# 4                   24
# 5                   18
# 6                    7
# 7                   24
# 8                   19
# 9                    0
# 10                  28
# 11                  19
# 12                  16
# 13                  16
# 14                  18
# 15                  24
# 16                  24
# 17                  19
# 18                   7
# 19                  29
# ..                 ...
# 40                  23
# 41                  23
# 42                  50
# 43                  66
# 44                  54
# 45                  48
# 46                  74
# 47                  51
# 48                  23
# 49                  76
# 50                  23
# 51                  23
# 52                  50
# 53                  19
# 54                  77
# 55                  23
# 56                  23
# 57                  72
# 58                  74
# 59                  75
# 60                  23
# 61                  78
# 62                  23
# 63                  43
# 64                  23
# 65                  16
# 66                  42
# 67                  70
# 68                  23
# 69                  51
#
# [808 rows x 9 columns]

# %%
df.to_csv("GapAnalysis_JvR1215.csv")
