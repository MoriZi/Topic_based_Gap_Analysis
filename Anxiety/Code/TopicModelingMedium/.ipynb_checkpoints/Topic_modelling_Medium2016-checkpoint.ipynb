# %% [markdown]
# ### Obtained Perplexity: -8.68, Coherence: 0.31, Best Number of Topics= 50

# %%
#Basic Libraries
import re
import numpy as np
import pandas as pd
from pprint import pprint
import sys
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
# spacy for lemmatization
import spacy
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

from topic_model_function import *

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
#Load Dataset
df=pd.read_csv('/Users/mahika.p/OneDrive - Cornell University/Anxiety/Topic_based_Gap_Analysis/Anxiety/Data/CSV/medium_text_2016.csv')
df = df.iloc[::5, :]
#getting rid of NaN
df=df.replace(np.nan, '', regex=True)
#Combining title and text
df["Post"] = df["title"] + df["text"]
#Now that we don't need Title or Text, we drop those columns before saving the file
df=df.drop(['title', 'text'], axis = 1)

# %%
df=df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.head()
# Out:
#    year                                               Post
# 0  2016  27 Minutes of Uber-Induced AnxietyAlternate ti...
# 1  2016  Thank you, Anxiety.I hate living with anxiety ...
# 2  2016  I’m Like A Broken MugTalking about your mental...
# 3  2016  New Year ResolutionsToday I am going to write ...
# 4  2016  Isaiah 60:1–2When I first thought about starti...

# %%
# Convert to list
data=df.Post.values.tolist()
# Remove new line characters
data=[re.sub('\s+', ' ', sent) for sent in data]
# Remove distracting single quotes
data=[re.sub("\'", "", sent) for sent in data]

# %%
#Function to clean up text
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

# %%
#Clean up text
data_words=list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['minutes', 'of', 'uber', 'induced', 'title', 'the', 'actual', 'thoughts', 'of', 'person', 'with', 'generalized', 'anxiety', 'disorder', 'trusting', 'total', 'stranger', 'to', 'drive', 'her', 'around', 'for', 'almost', 'half', 'an', 'hour', 'date', 'december', 'time', 'pm', 'pickup', 'location', 'san', 'francisco', 'international', 'airport', 'departures', 'terminal', 'door', 'destination', 'home', 'after', 'day', 'trip', 'to', 'ohio', 'visiting', 'my', 'family', 'wait', 'for', 'my', 'uber', 'driver', 'to', 'arrive', 'he', 'driving', 'black', 'prius', 'just', 'like', 'every', 'other', 'uber', 'driver', 'tonight', 'notice', 'for', 'the', 'first', 'time', 'that', 'the', 'phone', 'app', 'shows', 'the', 'license', 'plate', 'number', 'that', 'handy', 'manage', 'to', 'avoid', 'getting', 'into', 'the', 'wrong', 'car', 'the', 'driver', 'loads', 'my', 'suitcase', 'in', 'the', 'trunk', 'and', 'asks', 'me', 'which', 'route', 'usually', 'take', 'home', 've', 'never', 'been', 'asked', 'this', 'before', 'stupidly', 'say', 'don', 'know', 'the', 'area', 'very', 'well', 'just', 'take', 'the', 'gps', 'directions', 'and', 'so', 'my', 'anxiety', 'that', 'this', 'driver', 'is', 'going', 'to', 'abduct', 'me', 'begins', 'check', 'my', 'status', 'minutes', 'until', 'arrival', 'why', 'did', 'the', 'driver', 'ask', 'me', 'my', 'route', 'wonder', 'is', 'he', 'trying', 'to', 'find', 'out', 'whether', 'or', 'not', 'know', 'my', 'way', 'around', 'now', 'he', 'knows', 'don', 'he', 'going', 'to', 'abduct', 'me', 'there', 'no', 'way', 'he', 'would', 'ask', 'me', 'that', 'unless', 'he', 'wanted', 'to', 'abduct', 'me', 'check', 'the', 'driver', 'rating', 'stars', 'ok', 'so', 'he', 'probably', 'hasn', 'abducted', 'anyone', 'before', 'but', 'there', 'first', 'time', 'for', 'everything', 'he', 'could', 've', 'been', 'building', 'up', 'his', 'rating', 'waiting', 'to', 'abduct', 'an', 'unsuspecting', 'woman', 'at', 'the', 'airport', 'who', 'doesn', 'pay', 'enough', 'attention', 'to', 'know', 'which', 'route', 'she', 'usually', 'takes', 'take', 'stock', 'of', 'how', 'insane', 'these', 'thoughts', 'are', 'keep', 'thinking', 'them', 'anyway', 'he', 'takes', 'off', 'his', 'hat', 'why', 'did', 'he', 'take', 'off', 'his', 'hat', 'is', 'it', 'too', 'warm', 'or', 'is', 'he', 'trying', 'to', 'remove', 'anything', 'that', 'could', 'impede', 'his', 'vision', 'when', 'he', 'shoots', 'me', 'with', 'the', 'gun', 'that', 'is', 'most', 'definitely', 'under', 'his', 'seat', 'he', 'shifts', 'in', 'his', 'seat', 'is', 'he', 'reaching', 'for', 'the', 'gun', 'use', 'the', 'app', 'to', 'send', 'my', 'husband', 'the', 'trip', 'update', 'so', 'he', 'can', 'avenge', 'me', 'in', 'the', 'likely', 'case', 'of', 'my', 'demise', 'minutes', 'until', 'arrival', 'why', 'does', 'he', 'keep', 'moving', 'around', 'geez', 'there', 'are', 'lot', 'of', 'cars', 'on', 'the', 'road', 'forget', 'the', 'gun', 'll', 'probably', 'die', 'in', 'car', 'accident', 'before', 'he', 'has', 'the', 'time', 'to', 'use', 'it', 've', 'heard', 'that', 'car', 'accidents', 'are', 'the', 'leading', 'cause', 'of', 'death', 'of', 'people', 'under', 'the', 'age', 'of', 'didn', 'verify', 'the', 'statistics', 'but', 'that', 'sounds', 'about', 'right', 'wonder', 'what', 'the', 'statistics', 'are', 'for', 'people', 'who', 'die', 'via', 'car', 'crash', 'because', 'the', 'driver', 'is', 'distracted', 'trying', 'to', 'retrieve', 'gun', 'from', 'under', 'his', 'seat', 'minutes', 'until', 'arrival', 'we', 'seem', 'to', 'be', 'moving', 'in', 'the', 'direction', 'of', 'home', 'though', 'that', 'could', 'be', 'decoy', 'he', 'shifts', 'in', 'his', 'seat', 'again', 'why', 'does', 'he', 'keep', 'shifting', 'why', 'hasn', 'he', 'talked', 'to', 'me', 'since', 'asking', 'me', 'about', 'the', 'route', 'don', 'really', 'want', 'to', 'talk', 'but', 'maybe', 'it', 'bad', 'sign', 'that', 'he', 'hasn', 'said', 'anything', 'don', 'humanize', 'the', 'victim', 'it', 'would', 'be', 'harder', 'to', 'shoot', 'me', 'if', 'he', 'got', 'to', 'know', 'me', 'unle ...

# %%
# Build the bigram and trigram models
bigram=gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram=gensim.models.Phrases(bigram[data_words], threshold=100)

# %%
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod=gensim.models.phrases.Phraser(bigram)
trigram_mod=gensim.models.phrases.Phraser(trigram)

# %%
# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['minutes', 'of', 'uber', 'induced', 'title', 'the', 'actual', 'thoughts', 'of', 'person', 'with', 'generalized', 'anxiety', 'disorder', 'trusting', 'total', 'stranger', 'to', 'drive', 'her', 'around', 'for', 'almost', 'half', 'an', 'hour', 'date', 'december', 'time', 'pm', 'pickup', 'location', 'san_francisco', 'international', 'airport', 'departures', 'terminal', 'door', 'destination', 'home', 'after', 'day', 'trip', 'to', 'ohio', 'visiting', 'my', 'family', 'wait', 'for', 'my', 'uber', 'driver', 'to', 'arrive', 'he', 'driving', 'black', 'prius', 'just', 'like', 'every', 'other', 'uber', 'driver', 'tonight', 'notice', 'for', 'the', 'first', 'time', 'that', 'the', 'phone', 'app', 'shows', 'the', 'license', 'plate', 'number', 'that', 'handy', 'manage', 'to', 'avoid', 'getting', 'into', 'the', 'wrong', 'car', 'the', 'driver', 'loads', 'my', 'suitcase', 'in', 'the', 'trunk', 'and', 'asks', 'me', 'which', 'route', 'usually', 'take', 'home', 've', 'never', 'been', 'asked', 'this', 'before', 'stupidly', 'say', 'don', 'know', 'the', 'area', 'very', 'well', 'just', 'take', 'the', 'gps', 'directions', 'and', 'so', 'my', 'anxiety', 'that', 'this', 'driver', 'is', 'going', 'to', 'abduct', 'me', 'begins', 'check', 'my', 'status', 'minutes', 'until', 'arrival', 'why', 'did', 'the', 'driver', 'ask', 'me', 'my', 'route', 'wonder', 'is', 'he', 'trying', 'to', 'find', 'out', 'whether', 'or', 'not', 'know', 'my', 'way', 'around', 'now', 'he', 'knows', 'don', 'he', 'going', 'to', 'abduct', 'me', 'there', 'no', 'way', 'he', 'would', 'ask', 'me', 'that', 'unless', 'he', 'wanted', 'to', 'abduct', 'me', 'check', 'the', 'driver', 'rating', 'stars', 'ok', 'so', 'he', 'probably', 'hasn', 'abducted', 'anyone', 'before', 'but', 'there', 'first', 'time', 'for', 'everything', 'he', 'could', 've', 'been', 'building', 'up', 'his', 'rating', 'waiting', 'to', 'abduct', 'an', 'unsuspecting', 'woman', 'at', 'the', 'airport', 'who', 'doesn', 'pay', 'enough', 'attention', 'to', 'know', 'which', 'route', 'she', 'usually', 'takes', 'take', 'stock', 'of', 'how', 'insane', 'these', 'thoughts', 'are', 'keep', 'thinking', 'them', 'anyway', 'he', 'takes', 'off', 'his', 'hat', 'why', 'did', 'he', 'take', 'off', 'his', 'hat', 'is', 'it', 'too', 'warm', 'or', 'is', 'he', 'trying', 'to', 'remove', 'anything', 'that', 'could', 'impede', 'his', 'vision', 'when', 'he', 'shoots', 'me', 'with', 'the', 'gun', 'that', 'is', 'most', 'definitely', 'under', 'his', 'seat', 'he', 'shifts', 'in', 'his', 'seat', 'is', 'he', 'reaching', 'for', 'the', 'gun', 'use', 'the', 'app', 'to', 'send', 'my', 'husband', 'the', 'trip', 'update', 'so', 'he', 'can', 'avenge', 'me', 'in', 'the', 'likely', 'case', 'of', 'my', 'demise', 'minutes', 'until', 'arrival', 'why', 'does', 'he', 'keep', 'moving', 'around', 'geez', 'there', 'are', 'lot', 'of', 'cars', 'on', 'the', 'road', 'forget', 'the', 'gun', 'll', 'probably', 'die', 'in', 'car_accident', 'before', 'he', 'has', 'the', 'time', 'to', 'use', 'it', 've', 'heard', 'that', 'car', 'accidents', 'are', 'the', 'leading_cause', 'of', 'death', 'of', 'people', 'under', 'the', 'age', 'of', 'didn', 'verify', 'the', 'statistics', 'but', 'that', 'sounds', 'about', 'right', 'wonder', 'what', 'the', 'statistics', 'are', 'for', 'people', 'who', 'die', 'via', 'car', 'crash', 'because', 'the', 'driver', 'is', 'distracted', 'trying', 'to', 'retrieve', 'gun', 'from', 'under', 'his', 'seat', 'minutes', 'until', 'arrival', 'we', 'seem', 'to', 'be', 'moving', 'in', 'the', 'direction', 'of', 'home', 'though', 'that', 'could', 'be', 'decoy', 'he', 'shifts', 'in', 'his', 'seat', 'again', 'why', 'does', 'he', 'keep', 'shifting', 'why', 'hasn', 'he', 'talked', 'to', 'me', 'since', 'asking', 'me', 'about', 'the', 'route', 'don', 'really', 'want', 'to', 'talk', 'but', 'maybe', 'it', 'bad', 'sign', 'that', 'he', 'hasn', 'said', 'anything', 'don', 'humanize', 'the', 'victim', 'it', 'would', 'be', 'harder', 'to', 'shoot', 'me', 'if', 'he', 'got', 'to', 'know', 'me', 'unless', 'he', ...

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
data_words_nostops = remove_stopwords(data_words)
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load("en_core_web_sm")

# 1. Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
print(data_lemmatized[:1])

# 2. Create Dictionary needed for topic modelling
id2word = corpora.Dictionary(data_lemmatized)

# 3. Create Corpus
texts = data_lemmatized

# 4. Term Document Frequency and Create a bag of words
bow_corpus = bow(dictionary=id2word, processed_docs=texts)

# 5. Calculate low_tfidf_words
# Keep only words with tfidf ranking <= x * len(dictionary)
x = 0.2
total_word_count, DictDocFreq = tf_df(bow_corpus, id2word)
sorted_TFIDF = sort_tfidf(bow_corpus, total_word_count, DictDocFreq)
low_tfidf_words = get_low_tfidf_words(x, id2word, sorted_TFIDF)

# 6. Filter out least frequently used words
no_below = 0.01
keep_n = 10000
dict_least_freq_filtered = filter_least_frequent(id2word, texts, 
                                                 no_below, keep_n)

# 7. Filter out most commonly used words (i.e. words with low TF-IDF score)
dict_tfidf_filtered = filter_most_common(dict_least_freq_filtered, low_tfidf_words)

# 8. Create the second bag of words - bow_corpus_TFIDFfiltered, 
# created after least frequently and most commonly used words were filtered out.
corpus = bow(dict_tfidf_filtered, texts)

# View
[[(dict_tfidf_filtered[id], freq) for id, freq in cp] for cp in corpus[:1]]

# Build LDA model
# lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
#                                            id2word=dict_tfidf_filtered,
#                                            num_topics=34,
#                                            random_state=100,
#                                            update_every=1,
#                                            chunksize=100,
#                                            passes=10,
#                                            alpha='auto',
#                                            per_word_topics=True)
# Out:
# [['minute', 'uber', 'induce', 'title', 'actual', 'thought', 'person', 'generalize', 'anxiety', 'disorder', 'trust', 'total', 'stranger', 'drive', 'around', 'almost', 'half', 'hour', 'date', 'december', 'time', 'pm', 'pickup', 'location', 'international', 'airport', 'departure', 'terminal', 'door', 'destination', 'home', 'day', 'trip', 'ohio', 'visit', 'family', 'wait', 'uber', 'driver', 'arrive', 'drive', 'black', 'prius', 'uber', 'driver', 'tonight', 'notice', 'first', 'time', 'phone', 'app', 'show', 'license', 'plate', 'number', 'handy', 'manage', 'avoid', 'get', 'wrong', 'car', 'driver', 'load', 'suitcase', 'trunk', 'ask', 'route', 'usually', 'take', 'home', 'never', 'ask', 'stupidly', 'say', 'know', 'area', 'well', 'take', 'gps', 'direction', 'anxiety', 'driver', 'go', 'abduct', 'begin', 'check', 'status', 'minute', 'arrival', 'driver', 'ask', 'route', 'wonder', 'try', 'find', 'know', 'way', 'around', 'know', 'go', 'abduct', 'way', 'ask', 'want', 'abduct', 'check', 'driver', 'rating', 'star', 'probably', 'abduct', 'first', 'time', 'build', 'rating', 'wait', 'abduct', 'unsuspecting', 'woman', 'airport', 'pay', 'enough', 'attention', 'know', 'route', 'usually', 'take', 'take', 'stock', 'insane', 'thought', 'keep', 'think', 'anyway', 'take', 'hat', 'take', 'hat', 'warm', 'trying', 'remove', 'impede', 'vision', 'shoot', 'gun', 'definitely', 'seat', 'shift', 'seat', 'reach', 'gun', 'app', 'send', 'husband', 'trip', 'update', 'avenge', 'likely', 'case', 'demise', 'minute', 'arrival', 'keep', 'move', 'geez', 'lot', 'car', 'road', 'forget', 'gun', 'probably', 'die', 'car_accident', 'time', 'hear', 'car', 'accident', 'death', 'people', 'age', 'verify', 'statistic', 'sound', 'right', 'wonder', 'statistic', 'people', 'die', 'car', 'crash', 'driver', 'distract', 'trying', 'retrieve', 'gun', 'seat', 'minute', 'arrival', 'seem', 'move', 'direction', 'home', 'though', 'decoy', 'shift', 'seat', 'keep', 'shift', 'talk', 'ask', 'route', 'really', 'want', 'talk', 'maybe', 'bad', 'sign', 'say', 'humanize', 'victim', 'hard', 'shoot', 'get', 'know', 'personality', 'maybe', 'get', 'know', 'make', 'want', 'shoot', 'talk', 'know', 'start', 'talk', 'road', 'less', 'crowded', 'probably', 'mean', 'less', 'likely', 'hit', 'also', 'mean', 'less', 'potential', 'witness', 'abduction', 'shooting', 'really', 'take', 'uber', 'pool', 'impatience', 'go', 'kill', 'minute', 'arrival', 'highway', 'car', 'sticker', 'say', 'baby', 'board', 'imagine', 'vicious', 'killer', 'sticker', 'see', 'call', 'baby', 'ploy', 'lure', 'victim', 'car', 'really', 'picture', 'murderer', 'drive', 'prius', 'san', 'franciscan', 'notoriously', 'eco', 'friendly', 'car', 'choice', 'sadistic', 'abductor', 'prius', 'sake', 'hope', 'popularity', 'murderer', 'never', 'discover', 'general', 'public', 'minute', 'arrival', 'go', 'abduct', 'murder', 'seriously', 'run', 'time', 'maybe', 'plan', 'shoot', 'get', 'car', 'speed', 'less', 'mess', 'maybe', 'street', 'pull', 'gun', 'get', 'nightmare', 'mass', 'shooting', 'last', 'night', 'second', 'week', 'know', 'halfway', 'dream', 'time', 'wake', 'shoot', 'try', 'run', 'even', 'run', 'dream', 'think', 'bad', 'runner', 'dream', 'quite', 'feat', 'last', 'time', 'run', 'mile', 'th_grade', 'minute', 'second', 'time', 'take', 'run', 'mile', 'eta', 'minute', 'arrival', 'drive', 'empty', 'road', 'quiet', 'quiet', 'unnerve', 'sound', 'silence', 'block', 'see', 'build', 'red', 'unload', 'luggage', 'trunk', 'happy', 'holiday', 'say', 'walk', 'apartment', 'respond', 'put', 'key', 'lock', 'turn', 'build', 'set', 'stair', 'apartment', 'safe', 'survive', 'open', 'phone', 'app', 'rate', 'ride', 'star']]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-8f8655e5e464> in <module>
#      23 x = 0.2
#      24 total_word_count, DictDocFreq = tf_df(bow_corpus, id2word)
# ---> 25 sorted_TFIDF = sort_tfidf(bow_corpus, total_word_count, DictDocFreq)
#      26 low_tfidf_words = get_low_tfidf_words(x, id2word, sorted_TFIDF)
#      27
#
# ~/OneDrive - Cornell University/Anxiety/Topic_based_Gap_Analysis/Anxiety/Code/TopicModelingMedium/topic_model_function.py in sort_tfidf(bow_corpus, total_word_count, DictDocFreq)
#     165
#     166         # sort dictTFIDFbased on tfidf_score from high to low
# --> 167         sorted_TFIDF = sorted(dictTFIDF.items(), key=lambda w: w[1], reverse=True)
#     168
#     169     return sorted_TFIDF
#
# ~/OneDrive - Cornell University/Anxiety/Topic_based_Gap_Analysis/Anxiety/Code/TopicModelingMedium/topic_model_function.py in <lambda>(w)
#     165
#     166         # sort dictTFIDFbased on tfidf_score from high to low
# --> 167         sorted_TFIDF = sorted(dictTFIDF.items(), key=lambda w: w[1], reverse=True)
#     168
#     169     return sorted_TFIDF
#
# KeyboardInterrupt:

# %%
# Print the Keyword in the topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(32,
#   '0.303*"que" + 0.097*"nao" + 0.060*"para" + 0.051*"mas" + 0.048*"com" + '
#   '0.046*"por" + 0.036*"como" + 0.033*"mais" + 0.030*"ser" + 0.024*"nos"'),
#  (3,
#   '0.281*"episode" + 0.129*"cognitive" + 0.104*"vitamin" + 0.094*"healthy" + '
#   '0.076*"comparison" + 0.071*"miracle" + 0.069*"current" + 0.042*"curtain" + '
#   '0.022*"achieve" + 0.007*"balance"'),
#  (28,
#   '0.103*"diet" + 0.103*"oil" + 0.076*"clock" + 0.070*"oxygen" + '
#   '0.057*"contain" + 0.053*"hormone" + 0.049*"fat" + 0.035*"kindness" + '
#   '0.033*"regulate" + 0.032*"rhythm"'),
#  (25,
#   '0.604*"list" + 0.143*"website" + 0.108*"identity" + 0.036*"compel" + '
#   '0.014*"check" + 0.000*"urge" + 0.000*"going" + 0.000*"assistance" + '
#   '0.000*"charge" + 0.000*"encouragement"'),
#  (30,
#   '0.102*"dose" + 0.086*"un" + 0.072*"pour" + 0.068*"president" + 0.064*"la" + '
#   '0.062*"dan" + 0.059*"range" + 0.051*"category" + 0.049*"meme" + '
#   '0.047*"son"'),
#  (0,
#   '0.282*"happy" + 0.247*"happiness" + 0.147*"partner" + 0.071*"date" + '
#   '0.059*"confidence" + 0.055*"confident" + 0.034*"sex" + 0.027*"amazon" + '
#   '0.014*"restless" + 0.007*"path"'),
#  (5,
#   '0.208*"game" + 0.192*"play" + 0.092*"performance" + 0.064*"analysis" + '
#   '0.060*"show" + 0.047*"inevitable" + 0.033*"act" + 0.032*"ego" + '
#   '0.032*"role" + 0.022*"legal"'),
#  (21,
#   '0.165*"guide" + 0.079*"movement" + 0.079*"acceptance" + 0.060*"channel" + '
#   '0.059*"tie" + 0.056*"consciousness" + 0.053*"depth" + 0.048*"tense" + '
#   '0.045*"crack" + 0.043*"perfect"'),
#  (17,
#   '0.132*"burn" + 0.095*"color" + 0.071*"white" + 0.065*"rock" + 0.064*"dress" '
#   '+ 0.061*"occasionally" + 0.044*"blue" + 0.043*"corner" + 0.032*"skin" + '
#   '0.032*"five_minute"'),
#  (31,
#   '0.128*"drive" + 0.098*"road" + 0.071*"danger" + 0.067*"car" + '
#   '0.056*"victim" + 0.045*"status" + 0.039*"financial" + 0.033*"mountain" + '
#   '0.033*"overnight" + 0.032*"international"'),
#  (24,
#   '0.079*"social" + 0.041*"situation" + 0.035*"person" + 0.026*"trigger" + '
#   '0.024*"experience" + 0.023*"response" + 0.021*"avoid" + 0.018*"event" + '
#   '0.014*"other" + 0.014*"overcome"'),
#  (14,
#   '0.071*"disorder" + 0.034*"symptom" + 0.030*"treatment" + 0.029*"medication" '
#   '+ 0.024*"therapy" + 0.023*"doctor" + 0.022*"drug" + 0.021*"treat" + '
#   '0.019*"condition" + 0.019*"suffer"'),
#  (10,
#   '0.070*"worry" + 0.056*"thought" + 0.049*"control" + 0.044*"anxious" + '
#   '0.034*"mind" + 0.024*"situation" + 0.023*"future" + 0.020*"happen" + '
#   '0.020*"negative" + 0.018*"feeling"'),
#  (12,
#   '0.094*"say" + 0.065*"friend" + 0.044*"ask" + 0.041*"tell" + 0.033*"talk" + '
#   '0.025*"call" + 0.018*"family" + 0.016*"meet" + 0.016*"girl" + '
#   '0.016*"question"'),
#  (13,
#   '0.031*"home" + 0.030*"week" + 0.024*"hour" + 0.024*"eat" + 0.022*"new" + '
#   '0.018*"year" + 0.016*"morning" + 0.014*"dog" + 0.014*"last" + 0.013*"work"'),
#  (9,
#   '0.021*"leave" + 0.020*"back" + 0.018*"light" + 0.018*"eye" + 0.014*"hand" + '
#   '0.014*"sit" + 0.014*"begin" + 0.014*"room" + 0.013*"walk" + 0.012*"head"'),
#  (7,
#   '0.034*"write" + 0.026*"read" + 0.023*"book" + 0.016*"story" + 0.015*"work" '
#   '+ 0.012*"find" + 0.010*"world" + 0.010*"word" + 0.010*"idea" + '
#   '0.010*"come"'),
#  (20,
#   '0.040*"help" + 0.037*"depression" + 0.024*"year" + 0.017*"struggle" + '
#   '0.016*"many" + 0.016*"talk" + 0.015*"understand" + 0.015*"experience" + '
#   '0.015*"mental_health" + 0.014*"other"'),
#  (19,
#   '0.022*"work" + 0.015*"find" + 0.013*"also" + 0.012*"change" + 0.010*"many" '
#   '+ 0.009*"much" + 0.009*"self" + 0.008*"state" + 0.008*"first" + '
#   '0.008*"become"'),
#  (26,
#   '0.015*"try" + 0.015*"really" + 0.013*"still" + 0.013*"see" + 0.012*"much" + '
#   '0.011*"never" + 0.011*"start" + 0.011*"bad" + 0.010*"always" + '
#   '0.010*"come"')]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
# Out:
# Perplexity:  -8.503626396183227

# %%
# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=dict_tfidf_filtered, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.39992300710459194

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data):
    # Init output
    sent_topics_df=pd.DataFrame()
    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row=row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row=sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j==0:  # => dominant topic
                wp=ldamodel.show_topic(topic_num)
                topic_keywords=", ".join([word for word, prop in wp])
                sent_topics_df=sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns=['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
     # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_lemmatized)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head()
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0            26.0              0.2571
# 1            1            20.0              0.3558
# 2            2            26.0              0.5731
# 3            3            26.0              0.3735
# 4            4            26.0              0.3503
#
#                                             Keywords  \
# 0  try, really, still, see, much, never, start, b...
# 1  help, depression, year, struggle, many, talk, ...
# 2  try, really, still, see, much, never, start, b...
# 3  try, really, still, see, much, never, start, b...
# 4  try, really, still, see, much, never, start, b...
#
#                                                 Text
# 0  [minute, uber, induce, title, actual, thought,...
# 1  [thank, anxiety, hate, live, anxiety, never, t...
# 2  [broken, mugtalke, issue, hard, hard, scary, h...
# 3  [new, year, go, write, deeply, rooted, insecur...
# 4  [isaiah, first, think, start, blog, thought, o...

# %%
df_dominant_topic
# Out:
#       Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0               0            26.0              0.2571
# 1               1            20.0              0.3558
# 2               2            26.0              0.5731
# 3               3            26.0              0.3735
# 4               4            26.0              0.3503
# ...           ...             ...                 ...
# 2752         2752            26.0              0.3251
# 2753         2753            26.0              0.2764
# 2754         2754            26.0              0.3955
# 2755         2755            26.0              0.2202
# 2756         2756            26.0              0.4638
#
#                                                Keywords  \
# 0     try, really, still, see, much, never, start, b...
# 1     help, depression, year, struggle, many, talk, ...
# 2     try, really, still, see, much, never, start, b...
# 3     try, really, still, see, much, never, start, b...
# 4     try, really, still, see, much, never, start, b...
# ...                                                 ...
# 2752  try, really, still, see, much, never, start, b...
# 2753  try, really, still, see, much, never, start, b...
# 2754  try, really, still, see, much, never, start, b...
# 2755  try, really, still, see, much, never, start, b...
# 2756  try, really, still, see, much, never, start, b...
#
#                                                    Text
# 0     [minute, uber, induce, title, actual, thought,...
# 1     [thank, anxiety, hate, live, anxiety, never, t...
# 2     [broken, mugtalke, issue, hard, hard, scary, h...
# 3     [new, year, go, write, deeply, rooted, insecur...
# 4     [isaiah, first, think, start, blog, thought, o...
# ...                                                 ...
# 2752  [carry, air, count, breathe, count, diaphragm,...
# 2753  [pain, mattersi, know, feel, anger, constant, ...
# 2754  [wordsin, letter, apologize, reconciled, flaw,...
# 2755  [episode, recap, resolutionist, week, episode,...
# 2756  [safety, relative, anyway, time, abuse, love, ...
#
# [2757 rows x 5 columns]

# %%
doc_lens = [len(d) for d in df_dominant_topic.Text]

# Plot
plt.figure(figsize=(5,5), dpi=160)
plt.hist(doc_lens, bins = 1000, color='navy')
plt.text(750, 100, "Mean   : " + str(round(np.mean(doc_lens))))
plt.text(750,  90, "Median : " + str(round(np.median(doc_lens))))
plt.text(750,  80, "Stdev   : " + str(round(np.std(doc_lens))))
plt.text(750,  70, "1%ile    : " + str(round(np.quantile(doc_lens, q=0.01))))
plt.text(750,  60, "99%ile  : " + str(round(np.quantile(doc_lens, q=0.99))))

plt.gca().set(xlim=(0, 1000), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,1000,9))
plt.title('Distribution of Document Word Counts', fontdict=dict(size=22))
plt.show()

# %%
# 1. Wordcloud of Top N words in each topic
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(4, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
df_dominant_topic.to_csv("Medium2016.csv")

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(alpha='auto', corpus=corpus, num_topics=num_topics, 
                                                id2word=dictionary, random_state=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=dict_tfidf_filtered, corpus=corpus, 
                                                        texts=data_lemmatized, start=2, limit=100, step=8)

# %%
# Show graph
limit=100; start=2; step=8;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')

def differences(values, x):
    """
    Returns (optimal number of topics, largest jump, coherance value after jump)
    Params:
        values: list of coherance numbers, 
        x: num topics
    """
    max_diff = (0,0,0)
    for i in range(1,len(values)):
        if values[i]-values[i-1] > max_diff[1]:
            max_diff = (x[i], values[i]-values[i-1], values[i])
    return max_diff

differences(coherence_values, x)
