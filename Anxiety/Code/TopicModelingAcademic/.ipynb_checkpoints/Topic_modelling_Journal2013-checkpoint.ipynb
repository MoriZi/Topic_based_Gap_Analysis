# %% [markdown]
# ### Obtained Perplexity: -19.97, Coherence: 0.31, Best Number of Topics= 55

# %%
#Basic Libraries
import re
import numpy as np
import pandas as pd
from pprint import pprint
import sys
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
# spacy for lemmatization
import spacy
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
#Load Dataset
df=pd.read_csv('/home/smriti/Desktop/NLP/MITACS/Anxiety/Data/CSV/Academic/Acad_2013.csv')
#getting rid of NaN
df=df.replace(np.nan, '', regex=True)
#Combining title and text
df["Text"] = df["Title"] + df["Abstract"]
#Now that we don't need Title or Text, we drop those columns before saving the file
df=df.drop(['Title', 'Abstract'], axis = 1)
# Out:
# /home/smriti/.local/lib/python3.5/site-packages/pandas/core/computation/check.py:17: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
df=df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.head()
# Out:
#        StoreId      documentType  year  \
# 0  1.54199e+09   Journal Article  2013
# 1  1.54198e+09   Journal Article  2013
# 2  1.54198e+09   Journal Article  2013
# 3  1.54198e+09   Journal Article  2013
# 4  1.54198e+09   Journal Article  2013
#
#                                                 Text
# 0  Randomised controlled trial of group cognitive...
# 1  Randomized, placebo-controlled trial of cognit...
# 2  Mindfulness and acceptance-based group therapy...
# 3  Reducing depression in 9-10 year old children ...
# 4  Psychological treatment of hypnotic-dependent ...

# %%
# Convert to list
data=df.Text.values.tolist()
# Remove new line characters
data=[re.sub('\s+', ' ', sent) for sent in data]
# Remove distracting single quotes
data=[re.sub("\'", "", sent) for sent in data]

# %%
#Function to clean up text
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

# %%
#Clean up text
data_words=list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['randomised', 'controlled', 'trial', 'of', 'group', 'cognitive', 'behavioural', 'therapy', 'for', 'comorbid', 'anxiety', 'and', 'depression', 'in', 'older', 'adultsanxiety', 'and', 'depression', 'are', 'commonly', 'comorbid', 'in', 'older', 'adults', 'and', 'are', 'associated', 'with', 'worse', 'physical', 'and', 'mental', 'health', 'outcomes', 'and', 'poorer', 'response', 'to', 'psychological', 'and', 'pharmacological', 'treatments', 'however', 'little', 'research', 'has', 'examined', 'the', 'effectiveness', 'of', 'psychological', 'programs', 'to', 'treat', 'comorbid', 'anxiety', 'and', 'depression', 'in', 'older', 'adults', 'sixty', 'two', 'community', 'dwelling', 'adults', 'aged', 'over', 'years', 'with', 'comorbid', 'anxiety', 'and', 'depression', 'were', 'randomly', 'allocated', 'to', 'group', 'cognitive', 'behavioural', 'therapy', 'or', 'waitlist', 'condition', 'and', 'were', 'assessed', 'immediately', 'following', 'and', 'three', 'months', 'after', 'treatment', 'after', 'controlling', 'for', 'cognitive', 'ability', 'at', 'pre', 'treatment', 'cognitive', 'behaviour', 'therapy', 'resulted', 'in', 'significantly', 'greater', 'reductions', 'than', 'waitlist', 'on', 'symptoms', 'of', 'anxiety', 'and', 'depression', 'based', 'on', 'semi', 'structured', 'diagnostic', 'interview', 'rated', 'by', 'clinicians', 'unaware', 'of', 'treatment', 'condition', 'significant', 'time', 'by', 'treatment', 'interactions', 'were', 'also', 'found', 'for', 'self', 'report', 'measures', 'of', 'anxiety', 'and', 'depression', 'and', 'these', 'gains', 'were', 'maintained', 'at', 'the', 'three', 'month', 'follow', 'up', 'period', 'in', 'contrast', 'no', 'significant', 'differences', 'were', 'found', 'between', 'groups', 'on', 'measures', 'of', 'worry', 'and', 'well', 'being', 'in', 'conclusion', 'group', 'cognitive', 'behavioural', 'therapy', 'is', 'efficacious', 'in', 'reducing', 'comorbid', 'anxiety', 'and', 'depression', 'in', 'geriatric', 'populations', 'and', 'gains', 'maintain', 'for', 'at', 'least', 'three', 'months', 'copyright', 'elsevier', 'ltd']]

# %%
# Build the bigram and trigram models
bigram=gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram=gensim.models.Phrases(bigram[data_words], threshold=100)

# %%
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod=gensim.models.phrases.Phraser(bigram)
trigram_mod=gensim.models.phrases.Phraser(trigram)

# %%
# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['randomised_controlled_trial', 'of', 'group', 'cognitive', 'behavioural', 'therapy', 'for', 'comorbid', 'anxiety', 'and', 'depression', 'in', 'older', 'adultsanxiety', 'and', 'depression', 'are', 'commonly', 'comorbid', 'in', 'older_adults', 'and', 'are', 'associated', 'with', 'worse', 'physical', 'and', 'mental', 'health', 'outcomes', 'and', 'poorer', 'response', 'to', 'psychological', 'and', 'pharmacological', 'treatments', 'however', 'little', 'research', 'has', 'examined', 'the', 'effectiveness', 'of', 'psychological', 'programs', 'to', 'treat', 'comorbid', 'anxiety', 'and', 'depression', 'in', 'older_adults', 'sixty', 'two', 'community_dwelling', 'adults', 'aged', 'over', 'years', 'with', 'comorbid', 'anxiety', 'and', 'depression', 'were', 'randomly_allocated', 'to', 'group', 'cognitive', 'behavioural', 'therapy', 'or', 'waitlist', 'condition', 'and', 'were', 'assessed', 'immediately_following', 'and', 'three', 'months', 'after', 'treatment', 'after_controlling', 'for', 'cognitive', 'ability', 'at', 'pre', 'treatment', 'cognitive', 'behaviour', 'therapy', 'resulted', 'in', 'significantly', 'greater', 'reductions', 'than', 'waitlist', 'on', 'symptoms', 'of', 'anxiety', 'and', 'depression', 'based', 'on', 'semi_structured', 'diagnostic_interview', 'rated', 'by', 'clinicians', 'unaware', 'of', 'treatment', 'condition', 'significant', 'time', 'by', 'treatment', 'interactions', 'were', 'also', 'found', 'for', 'self_report', 'measures', 'of', 'anxiety', 'and', 'depression', 'and', 'these', 'gains', 'were', 'maintained', 'at', 'the', 'three', 'month_follow_up', 'period', 'in', 'contrast', 'no', 'significant', 'differences', 'were', 'found', 'between', 'groups', 'on', 'measures', 'of', 'worry', 'and', 'well_being', 'in', 'conclusion', 'group', 'cognitive', 'behavioural', 'therapy', 'is', 'efficacious', 'in', 'reducing', 'comorbid', 'anxiety', 'and', 'depression', 'in', 'geriatric', 'populations', 'and', 'gains', 'maintain', 'for', 'at', 'least', 'three', 'months', 'copyright_elsevier_ltd']

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
print(data_lemmatized[:1])

# Create Dictionary needed for topic modelling
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=55,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# [['randomised_controlle', 'trial', 'group', 'cognitive', 'behavioural', 'therapy', 'comorbid', 'anxiety', 'depression', 'old', 'adultsanxiety', 'depression', 'commonly', 'comorbid', 'older_adult', 'associate', 'bad', 'physical', 'mental', 'health', 'outcome', 'poor', 'response', 'psychological', 'pharmacological', 'treatment', 'however', 'little', 'research', 'examine', 'effectiveness', 'psychological', 'program', 'treat', 'comorbid', 'anxiety', 'depression', 'adult', 'comorbid', 'anxiety', 'depression', 'randomly_allocate', 'group', 'cognitive', 'behavioural', 'therapy', 'waitlist', 'condition', 'assess', 'month', 'treatment', 'control', 'cognitive', 'ability', 'pre', 'treatment', 'cognitive', 'behaviour', 'therapy', 'result', 'significantly', 'great', 'reduction', 'waitlist', 'symptom', 'anxiety', 'depression', 'base', 'semi_structured', 'rate', 'unaware', 'treatment', 'condition', 'significant', 'time', 'treatment', 'interaction', 'also', 'find', 'self', 'report', 'measure', 'anxiety', 'depression', 'gain', 'maintain', 'month_follow', 'period', 'contrast', 'significant', 'difference', 'find', 'group', 'measure', 'worry', 'well', 'conclusion', 'group', 'cognitive', 'behavioural', 'therapy', 'efficacious', 'reduce', 'comorbid', 'anxiety', 'depression', 'geriatric', 'population', 'gain', 'maintain', 'least', 'month']]

# %%
# Print the Keyword in the topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(17,
#   '0.000*"derived_neurotrophic" + 0.000*"beck" + 0.000*"synaptic" + '
#   '0.000*"neurotrophin" + 0.000*"neurotrophic" + 0.000*"lie" + 0.000*"glial" + '
#   '0.000*"elisa" + 0.000*"differentiation" + 0.000*"assume"'),
#  (52,
#   '0.000*"derived_neurotrophic" + 0.000*"beck" + 0.000*"synaptic" + '
#   '0.000*"neurotrophin" + 0.000*"neurotrophic" + 0.000*"lie" + 0.000*"glial" + '
#   '0.000*"elisa" + 0.000*"differentiation" + 0.000*"assume"'),
#  (44,
#   '0.000*"derived_neurotrophic" + 0.000*"beck" + 0.000*"synaptic" + '
#   '0.000*"neurotrophin" + 0.000*"neurotrophic" + 0.000*"lie" + 0.000*"glial" + '
#   '0.000*"elisa" + 0.000*"differentiation" + 0.000*"assume"'),
#  (34,
#   '0.000*"derived_neurotrophic" + 0.000*"beck" + 0.000*"synaptic" + '
#   '0.000*"neurotrophin" + 0.000*"neurotrophic" + 0.000*"lie" + 0.000*"glial" + '
#   '0.000*"elisa" + 0.000*"differentiation" + 0.000*"assume"'),
#  (35,
#   '0.000*"derived_neurotrophic" + 0.000*"beck" + 0.000*"synaptic" + '
#   '0.000*"neurotrophin" + 0.000*"neurotrophic" + 0.000*"lie" + 0.000*"glial" + '
#   '0.000*"elisa" + 0.000*"differentiation" + 0.000*"assume"'),
#  (32,
#   '0.000*"derived_neurotrophic" + 0.000*"beck" + 0.000*"synaptic" + '
#   '0.000*"neurotrophin" + 0.000*"neurotrophic" + 0.000*"lie" + 0.000*"glial" + '
#   '0.000*"elisa" + 0.000*"differentiation" + 0.000*"assume"'),
#  (39,
#   '0.000*"derived_neurotrophic" + 0.000*"beck" + 0.000*"synaptic" + '
#   '0.000*"neurotrophin" + 0.000*"neurotrophic" + 0.000*"lie" + 0.000*"glial" + '
#   '0.000*"elisa" + 0.000*"differentiation" + 0.000*"assume"'),
#  (13,
#   '0.000*"derived_neurotrophic" + 0.000*"beck" + 0.000*"synaptic" + '
#   '0.000*"neurotrophin" + 0.000*"neurotrophic" + 0.000*"lie" + 0.000*"glial" + '
#   '0.000*"elisa" + 0.000*"differentiation" + 0.000*"assume"'),
#  (12,
#   '0.000*"derived_neurotrophic" + 0.000*"beck" + 0.000*"synaptic" + '
#   '0.000*"neurotrophin" + 0.000*"neurotrophic" + 0.000*"lie" + 0.000*"glial" + '
#   '0.000*"elisa" + 0.000*"differentiation" + 0.000*"assume"'),
#  (9,
#   '0.000*"derived_neurotrophic" + 0.000*"beck" + 0.000*"synaptic" + '
#   '0.000*"neurotrophin" + 0.000*"neurotrophic" + 0.000*"lie" + 0.000*"glial" + '
#   '0.000*"elisa" + 0.000*"differentiation" + 0.000*"assume"'),
#  (46,
#   '0.068*"support" + 0.057*"information" + 0.033*"effect" + 0.032*"dimension" '
#   '+ 0.029*"highly" + 0.027*"enhance" + 0.027*"social" + 0.026*"provide" + '
#   '0.026*"additional" + 0.024*"daily"'),
#  (41,
#   '0.062*"non" + 0.055*"distress" + 0.047*"trauma" + 0.044*"factor" + '
#   '0.040*"relate" + 0.036*"model" + 0.034*"psychotic" + 0.032*"association" + '
#   '0.031*"psychosis" + 0.028*"group"'),
#  (30,
#   '0.264*"treatment" + 0.084*"cbt" + 0.073*"therapy" + 0.060*"outcome" + '
#   '0.044*"cognitive" + 0.033*"trial" + 0.030*"youth" + 0.026*"behavioral" + '
#   '0.024*"symptom" + 0.023*"receive"'),
#  (40,
#   '0.072*"risk" + 0.061*"behavior" + 0.051*"early" + 0.047*"model" + '
#   '0.031*"development" + 0.031*"anxiety" + 0.031*"social" + 0.028*"expose" + '
#   '0.026*"mediate" + 0.020*"underlie"'),
#  (25,
#   '0.074*"participant" + 0.057*"high" + 0.049*"anxiety" + 0.038*"low" + '
#   '0.035*"individual" + 0.033*"relationship" + 0.024*"report" + 0.021*"may" + '
#   '0.021*"associate" + 0.019*"healthy"'),
#  (36,
#   '0.064*"child" + 0.051*"association" + 0.029*"adolescent" + 0.025*"age" + '
#   '0.022*"parent" + 0.021*"follow" + 0.020*"anxiety" + 0.019*"tool" + '
#   '0.019*"problem" + 0.018*"symptom"'),
#  (1,
#   '0.057*"scale" + 0.023*"assessment" + 0.022*"use" + 0.018*"depression" + '
#   '0.018*"screen" + 0.018*"review" + 0.016*"result" + 0.015*"include" + '
#   '0.014*"anxiety" + 0.014*"method"'),
#  (5,
#   '0.082*"symptom" + 0.043*"self" + 0.037*"anxiety" + 0.026*"level" + '
#   '0.025*"course" + 0.024*"sensitivity" + 0.023*"limitation" + 0.022*"predict" '
#   '+ 0.021*"psychopathology" + 0.021*"panic"'),
#  (49,
#   '0.140*"disorder" + 0.089*"anxiety" + 0.037*"study" + 0.022*"may" + '
#   '0.022*"increase" + 0.021*"use" + 0.021*"risk" + 0.020*"sample" + '
#   '0.017*"factor" + 0.017*"control"'),
#  (26,
#   '0.056*"depression" + 0.051*"patient" + 0.036*"anxiety" + 0.030*"study" + '
#   '0.025*"result" + 0.018*"conclusion" + 0.016*"high" + 0.015*"method" + '
#   '0.014*"measure" + 0.013*"associate"')]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
# Out:
# Perplexity:  -19.778453379214742

# %%
# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.3195902546279311

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data):
    # Init output
    sent_topics_df=pd.DataFrame()
    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row=row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row=sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j==0:  # => dominant topic
                wp=ldamodel.show_topic(topic_num)
                topic_keywords=", ".join([word for word, prop in wp])
                sent_topics_df=sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns=['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
     # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_lemmatized)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head()
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0            26.0              0.5554
# 1            1            30.0              0.5463
# 2            2            26.0              0.3801
# 3            3            36.0              0.6080
# 4            4            51.0              0.4131
#
#                                             Keywords  \
# 0  depression, patient, anxiety, study, result, c...
# 1  treatment, cbt, therapy, outcome, cognitive, t...
# 2  depression, patient, anxiety, study, result, c...
# 3  child, association, adolescent, age, parent, f...
# 4  sleep, dependent, age, methodological, think, ...
#
#                                                 Text
# 0  [randomised_controlle, trial, group, cognitive...
# 1  [randomized, placebo, cognitive, behavioral, t...
# 2  [acceptance, base, group, therapy, traditional...
# 3  [reduce, depression, year_old, child, low, sch...
# 4  [psychological, treatment, hypnotic, dependent...

# %%
df_dominant_topic
# Out:
#      Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0              0            26.0              0.5554
# 1              1            30.0              0.5463
# 2              2            26.0              0.3801
# 3              3            36.0              0.6080
# 4              4            51.0              0.4131
# 5              5            37.0              0.6658
# 6              6            46.0              0.4076
# 7              7            37.0              0.6585
# 8              8            26.0              0.3373
# 9              9            30.0              0.5696
# 10            10            51.0              0.4320
# 11            11            36.0              0.6025
# 12            12            26.0              0.5424
# 13            13            46.0              0.4156
# 14            14             4.0              0.6829
# 15            15             5.0              0.6779
# 16            16            26.0              0.6804
# 17            17            26.0              0.6750
# 18            18             5.0              0.6813
# 19            19             4.0              0.6797
# 20            20            26.0              0.3122
# 21            21            49.0              0.5890
# 22            22            20.0              0.4108
# 23            23            53.0              0.5093
# 24            24            26.0              0.5780
# 25            25            54.0              0.4963
# 26            26             1.0              0.3988
# 27            27             1.0              0.2193
# 28            28             1.0              0.3809
# 29            29             1.0              0.2098
# ..           ...             ...                 ...
# 658          658            41.0              0.2621
# 659          659            49.0              0.4596
# 660          660            26.0              0.3015
# 661          661            26.0              0.1691
# 662          662            49.0              0.3260
# 663          663            49.0              0.2511
# 664          664            49.0              0.3224
# 665          665            49.0              0.2386
# 666          666            26.0              0.3669
# 667          667            49.0              0.4715
# 668          668            26.0              0.3714
# 669          669            49.0              0.4667
# 670          670            26.0              0.4417
# 671          671            49.0              0.3518
# 672          672            36.0              0.2234
# 673          673            26.0              0.2186
# 674          674            36.0              0.2080
# 675          675            26.0              0.4415
# 676          676            49.0              0.3371
# 677          677            26.0              0.2336
# 678          678            26.0              0.3601
# 679          679            26.0              0.4080
# 680          680            26.0              0.4212
# 681          681            26.0              0.2661
# 682          682            26.0              0.4104
# 683          683            26.0              0.4652
# 684          684            26.0              0.4859
# 685          685            49.0              0.3099
# 686          686            49.0              0.3236
# 687          687            41.0              0.2362
#
#                                               Keywords  \
# 0    depression, patient, anxiety, study, result, c...
# 1    treatment, cbt, therapy, outcome, cognitive, t...
# 2    depression, patient, anxiety, study, result, c...
# 3    child, association, adolescent, age, parent, f...
# 4    sleep, dependent, age, methodological, think, ...
# 5    face, unclear, superior, behavioral, identity,...
# 6    support, information, effect, dimension, highl...
# 7    face, unclear, superior, behavioral, identity,...
# 8    depression, patient, anxiety, study, result, c...
# 9    treatment, cbt, therapy, outcome, cognitive, t...
# 10   sleep, dependent, age, methodological, think, ...
# 11   child, association, adolescent, age, parent, f...
# 12   depression, patient, anxiety, study, result, c...
# 13   support, information, effect, dimension, highl...
# 14   subject, group, alcohol, condition, reduction,...
# 15   symptom, self, anxiety, level, course, sensiti...
# 16   depression, patient, anxiety, study, result, c...
# 17   depression, patient, anxiety, study, result, c...
# 18   symptom, self, anxiety, level, course, sensiti...
# 19   subject, group, alcohol, condition, reduction,...
# 20   depression, patient, anxiety, study, result, c...
# 21   disorder, anxiety, study, may, increase, use, ...
# 22   group, sad, social, small, improvement, partic...
# 23   cognitive, change, behavioural, cognition, rea...
# 24   depression, patient, anxiety, study, result, c...
# 25   score, high, rate, functional, complete, behav...
# 26   scale, assessment, use, depression, screen, re...
# 27   scale, assessment, use, depression, screen, re...
# 28   scale, assessment, use, depression, screen, re...
# 29   scale, assessment, use, depression, screen, re...
# ..                                                 ...
# 658  non, distress, trauma, factor, relate, model, ...
# 659  disorder, anxiety, study, may, increase, use, ...
# 660  depression, patient, anxiety, study, result, c...
# 661  depression, patient, anxiety, study, result, c...
# 662  disorder, anxiety, study, may, increase, use, ...
# 663  disorder, anxiety, study, may, increase, use, ...
# 664  disorder, anxiety, study, may, increase, use, ...
# 665  disorder, anxiety, study, may, increase, use, ...
# 666  depression, patient, anxiety, study, result, c...
# 667  disorder, anxiety, study, may, increase, use, ...
# 668  depression, patient, anxiety, study, result, c...
# 669  disorder, anxiety, study, may, increase, use, ...
# 670  depression, patient, anxiety, study, result, c...
# 671  disorder, anxiety, study, may, increase, use, ...
# 672  child, association, adolescent, age, parent, f...
# 673  depression, patient, anxiety, study, result, c...
# 674  child, association, adolescent, age, parent, f...
# 675  depression, patient, anxiety, study, result, c...
# 676  disorder, anxiety, study, may, increase, use, ...
# 677  depression, patient, anxiety, study, result, c...
# 678  depression, patient, anxiety, study, result, c...
# 679  depression, patient, anxiety, study, result, c...
# 680  depression, patient, anxiety, study, result, c...
# 681  depression, patient, anxiety, study, result, c...
# 682  depression, patient, anxiety, study, result, c...
# 683  depression, patient, anxiety, study, result, c...
# 684  depression, patient, anxiety, study, result, c...
# 685  disorder, anxiety, study, may, increase, use, ...
# 686  disorder, anxiety, study, may, increase, use, ...
# 687  non, distress, trauma, factor, relate, model, ...
#
#                                                   Text
# 0    [randomised_controlle, trial, group, cognitive...
# 1    [randomized, placebo, cognitive, behavioral, t...
# 2    [acceptance, base, group, therapy, traditional...
# 3    [reduce, depression, year_old, child, low, sch...
# 4    [psychological, treatment, hypnotic, dependent...
# 5    [attention, reduce, speech, mechanism, mediate...
# 6    [motivational, support, provide, email, improv...
# 7    [attention, reduce, speech, anxiety, mechanism...
# 8    [acceptance, base, group, therapy, traditional...
# 9    [randomized, placebo, cognitive, behavioral, t...
# 10   [psychological, treatment, hypnotic, dependent...
# 11   [reduce, depression, year_old, child, low, sch...
# 12   [randomised_controlle, trial, group, cognitive...
# 13   [motivational, support, provide, email, improv...
# 14   [effect, venlafaxine, cognitive, behavioral, t...
# 15   [mechanism, change, cognitive, behavioral, the...
# 16   [implementation, cognitive, routine, clinical,...
# 17   [implementation, cognitive, routine, clinical,...
# 18   [mechanism, change, cognitive, behavioral, the...
# 19   [effect, venlafaxine, cognitive, behavioral, t...
# 20   [emotional, reactivity, predictor, moderator, ...
# 21   [failure, capitalize, share, explore, positivi...
# 22   [psychological, treatment, disorder, individua...
# 23   [change, illness, related, cognition, rather, ...
# 24   [predictor, outcome, internet, base, cognitive...
# 25   [integrated, behavior, therapy, randomized_con...
# 26   [interpretation, viable, treatment, child, anx...
# 27   [recall, aversive, memory, decreases_condition...
# 28   [cognitive, behaviour, therapy, common, mental...
# 29   [recall, aversive, memory, decreases_condition...
# ..                                                 ...
# 658  [disturbance, basic, self, prodromal, symptom,...
# 659  [prefrontal, generalize, anxiety, panic, disor...
# 660  [subsyndromal, depression, prevalence, course,...
# 661  [assess, moodscope, background, moodscope, ent...
# 662  [role, impulsivity, depressive, anxiety, disor...
# 663  [severity, persistence, asthma, current, study...
# 664  [role, impulsivity, depressive, anxiety, disor...
# 665  [severity, persistence, asthma, study, goal, c...
# 666  [relate, cerebrospinal, marker, subject, cogni...
# 667  [global, prevalence, anxiety, disorder, meta, ...
# 668  [relate, cerebrospinal, marker, subject, mild,...
# 669  [global, prevalence, anxiety, disorder, regres...
# 670  [strongly, associate, investigate, causal, rel...
# 671  [association, anxiety, depressive, disorder, t...
# 672  [attention, orienting, evidence, specificity, ...
# 673  [neural, observable, self, anxiety, image, obs...
# 674  [attention, orienting, evidence, specificity, ...
# 675  [background, strongly, associate, mental, inve...
# 676  [association, anxiety, depressive, disorder, t...
# 677  [neural, observable, self, disorder, backgroun...
# 678  [psychological, treatment, anxiety, background...
# 679  [cognition, behaviour, co_morbid, psychiatric,...
# 680  [psychosocial, stressor, prognosis, major, dep...
# 681  [sleep_disturbance, depressive, argue, risk, f...
# 682  [stress, sensitivity, symptom, individual, cli...
# 683  [effectiveness, internet, base, cognitive, sev...
# 684  [childhood_adversity, schizophrenia, systemati...
# 685  [adverse, childhood, experience, relation, moo...
# 686  [structure, common, uncommon, mental, disorder...
# 687  [shame, cognition, psychosis, background, soci...
#
# [688 rows x 5 columns]

# %%
doc_lens = [len(d) for d in df_dominant_topic.Text]

# Plot
plt.figure(figsize=(16,7), dpi=160)
plt.hist(doc_lens, bins = 1000, color='navy')
plt.text(750, 100, "Mean   : " + str(round(np.mean(doc_lens))))
plt.text(750,  90, "Median : " + str(round(np.median(doc_lens))))
plt.text(750,  80, "Stdev   : " + str(round(np.std(doc_lens))))
plt.text(750,  70, "1%ile    : " + str(round(np.quantile(doc_lens, q=0.01))))
plt.text(750,  60, "99%ile  : " + str(round(np.quantile(doc_lens, q=0.99))))

plt.gca().set(xlim=(0, 1000), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,1000,9))
plt.title('Distribution of Document Word Counts', fontdict=dict(size=22))
plt.show()

# %%
# 1. Wordcloud of Top N words in each topic
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(4, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
df_dominant_topic.to_csv("Journal2013.csv")

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(alpha='auto', corpus=corpus, num_topics=20, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=2, limit=100, step=6)

# %%
# Show graph
limit=100; start=2; step=6;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
