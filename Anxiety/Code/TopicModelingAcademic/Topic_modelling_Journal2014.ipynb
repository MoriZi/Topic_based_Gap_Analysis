# %% [markdown]
# ### Obtained Perplexity: -16.44, Coherence: 0.38, Best Number of Topics= 56

# %%
#Basic Libraries
import re
import numpy as np
import pandas as pd
from pprint import pprint
import sys
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
# spacy for lemmatization
import spacy
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
#Load Dataset
df=pd.read_csv('/home/smriti/Desktop/NLP/MITACS/Anxiety/Data/CSV/Academic/Acad_2014.csv')
#getting rid of NaN
df=df.replace(np.nan, '', regex=True)
#Combining title and text
df["Text"] = df["Title"] + df["Abstract"]
#Now that we don't need Title or Text, we drop those columns before saving the file
df=df.drop(['Title', 'Abstract'], axis = 1)
# Out:
# /home/smriti/.local/lib/python3.5/site-packages/pandas/core/computation/check.py:17: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
df=df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.head()
# Out:
#        StoreId documentType  year  \
# 0  1.64194e+09      Feature  2014
# 1  1.64193e+09      Feature  2014
# 2  1.64193e+09      Feature  2014
# 3  1.64193e+09      Feature  2014
# 4  1.64193e+09      Feature  2014
#
#                                                 Text
# 0  Reductions in the internalising construct foll...
# 1  Internet cognitive behavioural treatment for o...
# 2  Work-related CBT versus vocational services as...
# 3  Therapist effects and IAPT Psychological Wellb...
# 4  Repetitive negative thinking as a transdiagnos...

# %%
# Convert to list
data=df.Text.values.tolist()
# Remove new line characters
data=[re.sub('\s+', ' ', sent) for sent in data]
# Remove distracting single quotes
data=[re.sub("\'", "", sent) for sent in data]

# %%
#Function to clean up text
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

# %%
#Clean up text
data_words=list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['reductions', 'in', 'the', 'internalising', 'construct', 'following', 'internet', 'delivered', 'treatment', 'for', 'anxiety', 'and', 'depression', 'in', 'primary', 'care', 'depressive', 'and', 'anxiety', 'disorders', 'are', 'different', 'manifestations', 'of', 'latent', 'internalising', 'construct', 'to', 'date', 'efficacy', 'studies', 'have', 'tended', 'to', 'focus', 'on', 'disorder', 'specific', 'outcomes', 'rather', 'than', 'underlying', 'dimensions', 'this', 'study', 'examined', 'the', 'effect', 'of', 'transdiagnostic', 'internet', 'delivered', 'cognitive', 'behavioural', 'therapy', 'icbt', 'on', 'the', 'internalising', 'construct', 'in', 'primary', 'care', 'sample', 'participants', 'included', 'patients', 'aged', 'years', 'or', 'over', 'who', 'were', 'prescribed', 'six', 'lesson', 'transdiagnostic', 'icbt', 'program', 'for', 'anxiety', 'and', 'depression', 'by', 'their', 'primary', 'healthcare', 'professional', 'all', 'patients', 'completed', 'the', 'patient', 'health', 'questionnaire', 'the', 'generalised', 'anxiety', 'disorder', 'item', 'scale', 'the', 'mini', 'social', 'phobia', 'inventory', 'and', 'the', 'panic', 'disorder', 'severity', 'self', 'report', 'scale', 'at', 'baseline', 'of', 'these', 'patients', 'completed', 'the', 'program', 'and', 'provided', 'data', 'on', 'each', 'of', 'these', 'scales', 'during', 'the', 'final', 'lesson', 'reductions', 'in', 'the', 'latent', 'internalising', 'construct', 'were', 'assessed', 'within', 'longitudinal', 'factor', 'analysis', 'framework', 'that', 'compared', 'internalising', 'factor', 'means', 'before', 'and', 'after', 'treatment', 'the', 'within', 'group', 'mean', 'reduction', 'in', 'the', 'latent', 'internalising', 'construct', 'was', 'large', 'es', 'se', 'lt', 'due', 'to', 'the', 'lack', 'of', 'control', 'group', 'between', 'group', 'reductions', 'in', 'the', 'latent', 'internalising', 'construct', 'could', 'not', 'be', 'investigated', 'this', 'study', 'demonstrated', 'that', 'there', 'are', 'clinically', 'significant', 'reductions', 'in', 'the', 'latent', 'internalising', 'construct', 'following', 'transdiagnostic', 'icbt', 'for', 'anxiety', 'and', 'depression']]

# %%
# Build the bigram and trigram models
bigram=gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram=gensim.models.Phrases(bigram[data_words], threshold=100)

# %%
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod=gensim.models.phrases.Phraser(bigram)
trigram_mod=gensim.models.phrases.Phraser(trigram)

# %%
# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['reductions', 'in', 'the', 'internalising_construct', 'following', 'internet_delivered', 'treatment', 'for', 'anxiety', 'and', 'depression', 'in', 'primary_care', 'depressive', 'and', 'anxiety', 'disorders', 'are', 'different', 'manifestations', 'of', 'latent', 'internalising_construct', 'to', 'date', 'efficacy', 'studies', 'have', 'tended', 'to', 'focus', 'on', 'disorder', 'specific', 'outcomes', 'rather_than', 'underlying', 'dimensions', 'this', 'study', 'examined', 'the', 'effect', 'of', 'transdiagnostic', 'internet_delivered', 'cognitive_behavioural_therapy', 'icbt', 'on', 'the', 'internalising_construct', 'in', 'primary_care', 'sample', 'participants', 'included', 'patients', 'aged_years', 'or', 'over', 'who', 'were', 'prescribed', 'six', 'lesson', 'transdiagnostic', 'icbt', 'program', 'for', 'anxiety', 'and', 'depression', 'by', 'their', 'primary', 'healthcare', 'professional', 'all', 'patients', 'completed', 'the', 'patient', 'health', 'questionnaire', 'the', 'generalised', 'anxiety', 'disorder', 'item', 'scale', 'the', 'mini', 'social', 'phobia', 'inventory', 'and', 'the', 'panic', 'disorder', 'severity', 'self_report', 'scale', 'at', 'baseline', 'of', 'these', 'patients', 'completed', 'the', 'program', 'and', 'provided', 'data', 'on', 'each', 'of', 'these', 'scales', 'during', 'the', 'final', 'lesson', 'reductions', 'in', 'the', 'latent', 'internalising_construct', 'were', 'assessed', 'within', 'longitudinal', 'factor', 'analysis', 'framework', 'that', 'compared', 'internalising', 'factor', 'means', 'before', 'and', 'after', 'treatment', 'the', 'within', 'group', 'mean', 'reduction', 'in', 'the', 'latent', 'internalising_construct', 'was', 'large', 'es', 'se', 'lt', 'due', 'to', 'the', 'lack', 'of', 'control', 'group', 'between', 'group', 'reductions', 'in', 'the', 'latent', 'internalising_construct', 'could', 'not', 'be', 'investigated', 'this', 'study', 'demonstrated', 'that', 'there', 'are', 'clinically', 'significant', 'reductions', 'in', 'the', 'latent', 'internalising_construct', 'following', 'transdiagnostic', 'icbt', 'for', 'anxiety', 'and', 'depression']

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
print(data_lemmatized[:1])

# Create Dictionary needed for topic modelling
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=56,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# [['reduction', 'internalising_construct', 'follow', 'internet_delivered', 'treatment', 'anxiety', 'depression', 'primary_care', 'depressive', 'anxiety', 'disorder', 'different', 'manifestation', 'latent', 'date', 'efficacy', 'study', 'tend', 'focus', 'disorder', 'specific', 'outcome', 'rather', 'underlying', 'dimension', 'study', 'examine', 'effect', 'transdiagnostic', 'therapy', 'icbt', 'sample', 'participant', 'include', 'patient', 'prescribe', 'lesson', 'program', 'anxiety', 'patient', 'complete', 'patient', 'health', 'questionnaire', 'generalise', 'anxiety', 'disorder', 'item', 'panic', 'disorder', 'severity', 'scale', 'baseline', 'patient', 'complete', 'program', 'provide', 'data', 'scale', 'final', 'lesson', 'reduction', 'latent', 'internalising_construct', 'assess', 'longitudinal', 'factor', 'analysis', 'framework', 'compare', 'internalise', 'factor', 'mean', 'treatment', 'group', 'mean', 'reduction', 'latent', 'large', 'group', 'reduction', 'latent', 'could', 'investigate', 'study', 'demonstrate', 'clinically', 'significant', 'reduction', 'latent', 'internalising_construct', 'follow', 'transdiagnostic', 'anxiety', 'depression']]

# %%
# Print the Keyword in the topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(5,
#   '0.000*"dapp" + 0.000*"though" + 0.000*"standardisation" + '
#   '0.000*"nonetheless" + 0.000*"lengthier" + 0.000*"abm" + 0.000*"rom" + '
#   '0.000*"personality_trait" + 0.000*"exacerbation" + 0.000*"generalisation"'),
#  (25,
#   '0.000*"dapp" + 0.000*"though" + 0.000*"standardisation" + '
#   '0.000*"nonetheless" + 0.000*"lengthier" + 0.000*"abm" + 0.000*"rom" + '
#   '0.000*"personality_trait" + 0.000*"exacerbation" + 0.000*"generalisation"'),
#  (47,
#   '0.000*"dapp" + 0.000*"though" + 0.000*"standardisation" + '
#   '0.000*"nonetheless" + 0.000*"lengthier" + 0.000*"abm" + 0.000*"rom" + '
#   '0.000*"personality_trait" + 0.000*"exacerbation" + 0.000*"generalisation"'),
#  (26,
#   '0.000*"dapp" + 0.000*"though" + 0.000*"standardisation" + '
#   '0.000*"nonetheless" + 0.000*"lengthier" + 0.000*"abm" + 0.000*"rom" + '
#   '0.000*"personality_trait" + 0.000*"exacerbation" + 0.000*"generalisation"'),
#  (16,
#   '0.000*"dapp" + 0.000*"though" + 0.000*"standardisation" + '
#   '0.000*"nonetheless" + 0.000*"lengthier" + 0.000*"abm" + 0.000*"rom" + '
#   '0.000*"personality_trait" + 0.000*"exacerbation" + 0.000*"generalisation"'),
#  (15,
#   '0.000*"dapp" + 0.000*"though" + 0.000*"standardisation" + '
#   '0.000*"nonetheless" + 0.000*"lengthier" + 0.000*"abm" + 0.000*"rom" + '
#   '0.000*"personality_trait" + 0.000*"exacerbation" + 0.000*"generalisation"'),
#  (0,
#   '0.000*"dapp" + 0.000*"though" + 0.000*"standardisation" + '
#   '0.000*"nonetheless" + 0.000*"lengthier" + 0.000*"abm" + 0.000*"rom" + '
#   '0.000*"personality_trait" + 0.000*"exacerbation" + 0.000*"generalisation"'),
#  (17,
#   '0.000*"dapp" + 0.000*"though" + 0.000*"standardisation" + '
#   '0.000*"nonetheless" + 0.000*"lengthier" + 0.000*"abm" + 0.000*"rom" + '
#   '0.000*"personality_trait" + 0.000*"exacerbation" + 0.000*"generalisation"'),
#  (55,
#   '0.000*"dapp" + 0.000*"though" + 0.000*"standardisation" + '
#   '0.000*"nonetheless" + 0.000*"lengthier" + 0.000*"abm" + 0.000*"rom" + '
#   '0.000*"personality_trait" + 0.000*"exacerbation" + 0.000*"generalisation"'),
#  (10,
#   '0.000*"dapp" + 0.000*"though" + 0.000*"standardisation" + '
#   '0.000*"nonetheless" + 0.000*"lengthier" + 0.000*"abm" + 0.000*"rom" + '
#   '0.000*"personality_trait" + 0.000*"exacerbation" + 0.000*"generalisation"'),
#  (11,
#   '0.199*"social" + 0.103*"anxious" + 0.080*"sad" + 0.068*"individual" + '
#   '0.033*"support" + 0.025*"sample" + 0.023*"difficulty" + 0.022*"anxiety" + '
#   '0.020*"medication" + 0.019*"class"'),
#  (35,
#   '0.567*"patient" + 0.024*"psychiatric" + 0.020*"often" + 0.019*"shame" + '
#   '0.014*"compare" + 0.013*"comorbiditie" + 0.013*"may" + 0.011*"second" + '
#   '0.011*"likely" + 0.011*"ratio"'),
#  (9,
#   '0.057*"positive" + 0.055*"negative" + 0.053*"psychosis" + 0.029*"day" + '
#   '0.028*"group" + 0.025*"participant" + 0.021*"event" + 0.020*"high" + '
#   '0.020*"level" + 0.017*"could"'),
#  (23,
#   '0.202*"treatment" + 0.066*"therapy" + 0.053*"outcome" + 0.049*"cbt" + '
#   '0.024*"follow" + 0.024*"cognitive" + 0.024*"improvement" + 0.022*"group" + '
#   '0.020*"trial" + 0.020*"participant"'),
#  (13,
#   '0.113*"mental" + 0.101*"health" + 0.069*"woman" + 0.055*"prevalence" + '
#   '0.043*"factor" + 0.037*"risk" + 0.035*"suicide" + 0.021*"country" + '
#   '0.021*"population" + 0.018*"adjust"'),
#  (38,
#   '0.061*"anxiety" + 0.042*"cognitive" + 0.033*"bias" + 0.028*"mediate" + '
#   '0.026*"process" + 0.026*"task" + 0.024*"control" + 0.024*"attention" + '
#   '0.024*"group" + 0.023*"processing"'),
#  (52,
#   '0.044*"anxiety" + 0.040*"depression" + 0.026*"information" + '
#   '0.025*"measure" + 0.024*"present" + 0.023*"study" + 0.020*"correlate" + '
#   '0.017*"provide" + 0.017*"influence" + 0.016*"development"'),
#  (8,
#   '0.075*"depression" + 0.073*"depressive" + 0.058*"symptom" + 0.043*"anxiety" '
#   '+ 0.035*"major" + 0.034*"adolescent" + 0.027*"disorder" + 0.026*"month" + '
#   '0.023*"year" + 0.020*"group"'),
#  (14,
#   '0.326*"disorder" + 0.091*"anxiety" + 0.039*"specific" + 0.033*"model" + '
#   '0.025*"factor" + 0.021*"diagnostic" + 0.020*"generalize" + '
#   '0.019*"limitation" + 0.016*"association" + 0.015*"diagnosis"'),
#  (29,
#   '0.037*"anxiety" + 0.034*"study" + 0.023*"result" + 0.022*"associate" + '
#   '0.019*"use" + 0.015*"high" + 0.014*"may" + 0.014*"level" + 0.014*"abstract" '
#   '+ 0.014*"source_journal"')]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
# Out:
# Perplexity:  -16.401016191926868

# %%
# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.3846762724474385

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data):
    # Init output
    sent_topics_df=pd.DataFrame()
    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row=row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row=sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j==0:  # => dominant topic
                wp=ldamodel.show_topic(topic_num)
                topic_keywords=", ".join([word for word, prop in wp])
                sent_topics_df=sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns=['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
     # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_lemmatized)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head()
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0            23.0              0.2477
# 1            1            23.0              0.4116
# 2            2            29.0              0.6280
# 3            3            29.0              0.4427
# 4            4             8.0              0.4859
#
#                                             Keywords  \
# 0  treatment, change, outcome, therapy, cbt, inte...
# 1  treatment, change, outcome, therapy, cbt, inte...
# 2  anxiety, disorder, patient, study, result, dep...
# 3  anxiety, disorder, patient, study, result, dep...
# 4  disorder, symptom, anxiety, depression, depres...
#
#                                                 Text
# 0  [reduction, internalising_construct, follow, i...
# 1  [treatment, obsessive_compulsive, disorder, ra...
# 2  [work, relate, cbt, vocational, service, usual...
# 3  [therapist, effect, iapt, psychological, wellb...
# 4  [repetitive, negative, thinking, transdiagnost...

# %%
df_dominant_topic
# Out:
#      Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0              0            23.0              0.2477
# 1              1            23.0              0.4116
# 2              2            29.0              0.6280
# 3              3            29.0              0.4427
# 4              4             8.0              0.4859
# 5              5            29.0              0.6921
# 6              6            29.0              0.3993
# 7              7            29.0              0.4589
# 8              8            23.0              0.5487
# 9              9            19.0              0.4852
# 10            10            29.0              0.2979
# 11            11            29.0              0.4065
# 12            12            29.0              0.4490
# 13            13            29.0              0.2429
# 14            14            23.0              0.3505
# 15            15            23.0              0.5046
# 16            16            23.0              0.3474
# 17            17            29.0              0.4151
# 18            18            23.0              0.4499
# 19            19            23.0              0.4075
# 20            20            23.0              0.3800
# 21            21            23.0              0.2554
# 22            22            23.0              0.3976
# 23            23             1.0              0.5868
# 24            24            23.0              0.5348
# 25            25            23.0              0.5353
# 26            26             1.0              0.5957
# 27            27            23.0              0.2567
# 28            28            23.0              0.5412
# 29            29            23.0              0.3995
# ..           ...             ...                 ...
# 722          722             8.0              0.4915
# 723          723            23.0              0.5057
# 724          724            29.0              0.3127
# 725          725            29.0              0.7067
# 726          726            29.0              0.7010
# 727          727            29.0              0.2691
# 728          728            29.0              0.5055
# 729          729             8.0              0.4974
# 730          730            29.0              0.3166
# 731          731            23.0              0.4887
# 732          732            29.0              0.3983
# 733          733            23.0              0.3854
# 734          734            29.0              0.3698
# 735          735             8.0              0.3353
# 736          736            29.0              0.3377
# 737          737            29.0              0.3910
# 738          738            29.0              0.4004
# 739          739             8.0              0.3589
# 740          740            29.0              0.4582
# 741          741             8.0              0.3223
# 742          742            29.0              0.3395
# 743          743            29.0              0.3596
# 744          744            29.0              0.3783
# 745          745            29.0              0.3574
# 746          746             8.0              0.3325
# 747          747             8.0              0.3213
# 748          748             8.0              0.3543
# 749          749            29.0              0.4704
# 750          750            29.0              0.4234
# 751          751            29.0              0.4083
#
#                                               Keywords  \
# 0    treatment, change, outcome, therapy, cbt, inte...
# 1    treatment, change, outcome, therapy, cbt, inte...
# 2    anxiety, disorder, patient, study, result, dep...
# 3    anxiety, disorder, patient, study, result, dep...
# 4    disorder, symptom, anxiety, depression, depres...
# 5    anxiety, disorder, patient, study, result, dep...
# 6    anxiety, disorder, patient, study, result, dep...
# 7    anxiety, disorder, patient, study, result, dep...
# 8    treatment, change, outcome, therapy, cbt, inte...
# 9    increase, neural, effect, response, decrease, ...
# 10   anxiety, disorder, patient, study, result, dep...
# 11   anxiety, disorder, patient, study, result, dep...
# 12   anxiety, disorder, patient, study, result, dep...
# 13   anxiety, disorder, patient, study, result, dep...
# 14   treatment, change, outcome, therapy, cbt, inte...
# 15   treatment, change, outcome, therapy, cbt, inte...
# 16   treatment, change, outcome, therapy, cbt, inte...
# 17   anxiety, disorder, patient, study, result, dep...
# 18   treatment, change, outcome, therapy, cbt, inte...
# 19   treatment, change, outcome, therapy, cbt, inte...
# 20   treatment, change, outcome, therapy, cbt, inte...
# 21   treatment, change, outcome, therapy, cbt, inte...
# 22   treatment, change, outcome, therapy, cbt, inte...
# 23   distress, internalize, model, effect, correlat...
# 24   treatment, change, outcome, therapy, cbt, inte...
# 25   treatment, change, outcome, therapy, cbt, inte...
# 26   distress, internalize, model, effect, correlat...
# 27   treatment, change, outcome, therapy, cbt, inte...
# 28   treatment, change, outcome, therapy, cbt, inte...
# 29   treatment, change, outcome, therapy, cbt, inte...
# ..                                                 ...
# 722  disorder, symptom, anxiety, depression, depres...
# 723  treatment, change, outcome, therapy, cbt, inte...
# 724  anxiety, disorder, patient, study, result, dep...
# 725  anxiety, disorder, patient, study, result, dep...
# 726  anxiety, disorder, patient, study, result, dep...
# 727  anxiety, disorder, patient, study, result, dep...
# 728  anxiety, disorder, patient, study, result, dep...
# 729  disorder, symptom, anxiety, depression, depres...
# 730  anxiety, disorder, patient, study, result, dep...
# 731  treatment, change, outcome, therapy, cbt, inte...
# 732  anxiety, disorder, patient, study, result, dep...
# 733  treatment, change, outcome, therapy, cbt, inte...
# 734  anxiety, disorder, patient, study, result, dep...
# 735  disorder, symptom, anxiety, depression, depres...
# 736  anxiety, disorder, patient, study, result, dep...
# 737  anxiety, disorder, patient, study, result, dep...
# 738  anxiety, disorder, patient, study, result, dep...
# 739  disorder, symptom, anxiety, depression, depres...
# 740  anxiety, disorder, patient, study, result, dep...
# 741  disorder, symptom, anxiety, depression, depres...
# 742  anxiety, disorder, patient, study, result, dep...
# 743  anxiety, disorder, patient, study, result, dep...
# 744  anxiety, disorder, patient, study, result, dep...
# 745  anxiety, disorder, patient, study, result, dep...
# 746  disorder, symptom, anxiety, depression, depres...
# 747  disorder, symptom, anxiety, depression, depres...
# 748  disorder, symptom, anxiety, depression, depres...
# 749  anxiety, disorder, patient, study, result, dep...
# 750  anxiety, disorder, patient, study, result, dep...
# 751  anxiety, disorder, patient, study, result, dep...
#
#                                                   Text
# 0    [reduction, internalising_construct, follow, i...
# 1    [treatment, obsessive_compulsive, disorder, ra...
# 2    [work, relate, cbt, vocational, service, usual...
# 3    [therapist, effect, iapt, psychological, wellb...
# 4    [repetitive, negative, thinking, transdiagnost...
# 5    [routine, clinical, practice, treatment, choic...
# 6    [program, adjunctive, treatment, stress, disor...
# 7    [effectiveness, self, help, mindfulness, base,...
# 8    [randomised_controlle, trial, face, face, pure...
# 9    [impact, cognitive, behavioral, therapy, anxie...
# 10   [predict, rapid, treatment, panic, disorder, r...
# 11   [fear, extinction, implication, assessment, tr...
# 12   [behavioural, perspective, aetiology, treatmen...
# 13   [attention, training, technique, self, focus, ...
# 14   [parent, cognitive, behavioral, intervention, ...
# 15   [combat, expose, ond, military, veteran, preli...
# 16   [base, disorder, specific, treatment, program,...
# 17   [therapy, update, attract, lot, interest, last...
# 18   [randomized_controlle, trial, internet, base, ...
# 19   [dialectical, behaviour, therapy, inform, deli...
# 20   [feasibility, mode, treatment, delivery, child...
# 21   [reduction, negative, repetitive, thinking, tr...
# 22   [dialectical_behavior, therapy, skill, transdi...
# 23   [effect, anxiety, sensitivity, intervention, a...
# 24   [clinical, effectiveness, internet, group, bas...
# 25   [clinical, effectiveness, internet, group, bas...
# 26   [effect, anxiety, sensitivity, intervention, a...
# 27   [reduction, negative, repetitive, thinking, tr...
# 28   [individually, tailor, internet_delivered, cog...
# 29   [dialectical_behavior, therapy, skill, transdi...
# ..                                                 ...
# 722  [trajectory, function, remission, anxiety, dis...
# 723  [randomized_controlle, comparison, integrative...
# 724  [biased, attention, threat, paediatric, anxiet...
# 725  [psychological, characteristic, motivation, wo...
# 726  [psychological, characteristic, motivation, wo...
# 727  [boundary, internalize, externalize, genetic, ...
# 728  [train, primary, health, care, worker, mental,...
# 729  [trajectory, function, remission, anxiety, dis...
# 730  [biased, attention, threat, paediatric, anxiet...
# 731  [randomized_controlle, comparison, integrative...
# 732  [depression, relate, absence, optimistically_b...
# 733  [prevention, background, clinical, equipoise, ...
# 734  [social, fear, anxiety, high, prevalence, asso...
# 735  [reciprocal, effect, stable, temporary, compon...
# 736  [alter, top, bottom, processing, fear_conditio...
# 737  [age, onset, obsessive_compulsive, disorder, a...
# 738  [change, prevalence, depression, anxiety, foll...
# 739  [transdiagnostic, disorder, specific, model, t...
# 740  [lesson, learn, psychosis, high, risk, state, ...
# 741  [positive, negative, predict, development, new...
# 742  [paradoxical, effect, antidepressant, treatmen...
# 743  [alter, top, bottom, processing, panic, disord...
# 744  [social, fear, social, anxiety, disorder, back...
# 745  [paradoxical, effect, antidepressant, treatmen...
# 746  [reciprocal, effect, stable, temporary, compon...
# 747  [positive, negative, predict, development, new...
# 748  [transdiagnostic, disorder, specific, model, t...
# 749  [lesson, learn, psychosis, high, risk, state, ...
# 750  [change, prevalence, depression, anxiety, foll...
# 751  [age, onset, obsessive_compulsive, disorder, a...
#
# [752 rows x 5 columns]

# %%
doc_lens = [len(d) for d in df_dominant_topic.Text]

# Plot
plt.figure(figsize=(16,7), dpi=160)
plt.hist(doc_lens, bins = 1000, color='navy')
plt.text(750, 100, "Mean   : " + str(round(np.mean(doc_lens))))
plt.text(750,  90, "Median : " + str(round(np.median(doc_lens))))
plt.text(750,  80, "Stdev   : " + str(round(np.std(doc_lens))))
plt.text(750,  70, "1%ile    : " + str(round(np.quantile(doc_lens, q=0.01))))
plt.text(750,  60, "99%ile  : " + str(round(np.quantile(doc_lens, q=0.99))))

plt.gca().set(xlim=(0, 1000), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,1000,9))
plt.title('Distribution of Document Word Counts', fontdict=dict(size=22))
plt.show()

# %%
# 1. Wordcloud of Top N words in each topic
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(4, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
df_dominant_topic.to_csv("Journal2014.csv")

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(alpha='auto', corpus=corpus, num_topics=20, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=2, limit=100, step=6)

# %%
# Show graph
limit=100; start=2; step=6;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
