# %%
import pandas as pd
df=pd.read_csv('rAnxiety2011.csv')
df
# Out:
#     Unnamed: 0                                              Title  \
# 0            0  What it feels like walking into a Cafeteria. C...
# 1            1  Hey. You know what? You're going to be okay, y...
# 2            2                               This is all I want.
# 3            3  Saw this in r/getmotivated, thought we could u...
# 4            4                       If only it were this easy...
# 5            5          Is anyone else afraid of their voicemail?
# 6            6  I can't be the only one who reacts this way......
# 7            7               Frequent lurker to r/anxiety (First)
# 8            8                                     It gets better
# 9            9                                  Just let me live!
# 10          10                           Because fuck you, brain.
# 11          11                Make everything ok with one button!
# 12          12            A lighthearted image that made me laugh
# ...

# %%
print(len(df))
# Out:
# 25
